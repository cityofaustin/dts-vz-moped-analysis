# %% [markdown]
# # Project type level analysis

# %%
import psycopg2
import json
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import LineString, MultiLineString
import matplotlib.pyplot as plt
import re

from config import DB_VISION_ZERO, DB_MOPED
from helper import dict_factory, to_json_list


def get_data(query, cursor):
    """
    Get data from database
    """
    cursor.execute(query)
    data = cursor.fetchall()
    field_names = [i[0] for i in cursor.description]
    df = pd.DataFrame(data, columns=field_names)

    return df

conn_vz = psycopg2.connect(
    dbname = DB_VISION_ZERO['dbname'],
    user = DB_VISION_ZERO["user"],
    host = DB_VISION_ZERO["host"],
    password = DB_VISION_ZERO["password"],
    port=5432
)

conn_moped = psycopg2.connect(
    dbname = DB_MOPED["dbname"],
    user = DB_MOPED["user"],
    host = DB_MOPED["host"],
    password = DB_MOPED["password"],
    port = 5432
)

cursor_vz = conn_vz.cursor()
cursor_moped = conn_moped.cursor()

# %% [markdown]
# ## Moped data

# %%
# Creating moped dataframe
QUERY_MOPED = """SELECT project_id, project_component_id, geometry, 
line_geometry, substantial_completion_date, 
substantial_completion_date_estimated, completion_date, completion_end_date,
component_name FROM component_arcgis_online_view"""

# Creating moped dataframe
df_moped = get_data(QUERY_MOPED, cursor_moped)

# Dropping observations where substantial completion date and component type are missing
df_moped_filter = df_moped.dropna(subset=['substantial_completion_date', 
                                          'component_name',
                                          'line_geometry'])

# %%
# Getting project types
project_types_counts = df_moped_filter['component_name'].value_counts()
project_types = project_types_counts.index.tolist()

# %%
# Convert timestamp columns to string using .loc
timestamp_columns = ["substantial_completion_date",
                     "substantial_completion_date_estimated", 
                     "completion_date", 
                     "completion_end_date"]

for col in timestamp_columns:
    df_moped_filter.loc[:, col] = df_moped_filter[col].astype(str)

# Geometry transformation using shape
df_moped_filter.loc[:, "geometry"] = df_moped_filter["geometry"].apply(lambda x: shape(x) if x is not None else None)
df_moped_filter.loc[:, "line_geometry"] = df_moped_filter["line_geometry"].apply(lambda x: shape(x) if x is not None else None)

# Create GeoDataFrame
gdf_moped = gpd.GeoDataFrame(df_moped_filter, geometry="geometry")

# %%
# Adding a unique ID column to the moped data frame
gdf_moped.insert(0, 'moped_component_id', range(1, 1 + len(gdf_moped)))

# %% [markdown]
# ## VisionZero

# %%
# Creaing vision zero dataframe
QUERY_CRASH_DATA = """SELECT crash_id, crash_fatal_fl, crash_date, road_constr_zone_fl, latitude, longitude, tot_injry_cnt, death_cnt, est_comp_cost 
FROM atd_txdot_crashes"""

df_vz = get_data(QUERY_CRASH_DATA, cursor_vz)

# Keepiing only those observations where x-y coordinates are present
df_vz_filter = df_vz[df_vz['latitude'].notnull() & df_vz['longitude'].notnull()]

# Convert timestamp columns to string using .loc
timestamp_columns = ["crash_date"]

for col in timestamp_columns:
    df_vz_filter.loc[:, col] = df_vz_filter[col].astype(str)


# Creating geodataframe
gdf_vz = gpd.GeoDataFrame(df_vz_filter,
                          geometry=gpd.points_from_xy(df_vz_filter.longitude,
                                                      df_vz_filter.latitude),
                                                      crs='EPSG:4326')

# %% [markdown]
# ## Spatial join

# %%
# Creating buffer for joining
gdf_moped = gdf_moped.set_geometry('line_geometry')
gdf_moped.set_crs(epsg=4326, inplace=True)
gdf_moped_proj = gdf_moped.to_crs(epsg=32614)
buffer_distance = 20

gdf_moped_proj = gdf_moped.to_crs(epsg=32614)

gdf_moped_proj['buffered_geometry'] = gdf_moped_proj.geometry.buffer(buffer_distance)
buffered_moped_gdf = gdf_moped_proj.set_geometry('buffered_geometry').to_crs('EPSG:4326')

# %%
# Creating dataframes for each project type
project_dataframes = {}

# Loop over each category and save the subset DataFrame to a CSV file
for project in project_types:
    # Subset the DataFrame based on the current category
    subset_df = df_moped[df_moped['component_name'] == project]
    
    # Sanitize the category name for use in a variable name
    sanitized_project = re.sub(r'[^a-zA-Z0-9]', '_', project)
    
    # Store the subset DataFrame in the dictionary
    project_dataframes[sanitized_project] = subset_df

# %%
project_dataframes
# Out:
# {'Bike_Lane':        project_id  project_component_id  \
#  26             22               10465.0
#  35             22               10463.0
#  294           246               11526.0
#  370           278               11605.0
#  375           279               11525.0
#  ...           ...                   ...
#  12026        3485               12304.0
#  12029        3485               12302.0
#  12034        3487               12312.0
#  12104        3525               12414.0
#  12142        3536               12525.0
#
#                                                  geometry  \
#  26     {'type': 'MultiLineString', 'coordinates': [[[...
#  35     {'type': 'MultiLineString', 'coordinates': [[[...
#  294    {'type': 'MultiLineString', 'coordinates': [[[...
#  370    {'type': 'MultiLineString', 'coordinates': [[[...
#  375    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12026  {'type': 'MultiLineString', 'coordinates': [[[...
#  12029  {'type': 'MultiLineString', 'coordinates': [[[...
#  12034  {'type': 'MultiLineString', 'coordinates': [[[...
#  12104  {'type': 'MultiLineString', 'coordinates': [[[...
#  12142  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  26     {'type': 'MultiLineString', 'coordinates': [[[...
#  35     {'type': 'MultiLineString', 'coordinates': [[[...
#  294    {'type': 'MultiLineString', 'coordinates': [[[...
#  370    {'type': 'MultiLineString', 'coordinates': [[[...
#  375    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12026  {'type': 'MultiLineString', 'coordinates': [[[...
#  12029  {'type': 'MultiLineString', 'coordinates': [[[...
#  12034  {'type': 'MultiLineString', 'coordinates': [[[...
#  12104  {'type': 'MultiLineString', 'coordinates': [[[...
#  12142  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  26                            NaT                                   NaT
#  35                            NaT                                   NaT
#  294                           NaT                                   NaT
#  370     2021-12-01 06:00:00+00:00                                   NaT
#  375                           NaT                                   NaT
#  ...                           ...                                   ...
#  12026   2019-10-01 05:00:00+00:00                                   NaT
#  12029   2019-10-01 05:00:00+00:00                                   NaT
#  12034   2020-08-01 05:00:00+00:00                                   NaT
#  12104                         NaT                                   NaT
#  12142                         NaT             2024-06-01 05:00:00+00:00
#
#        completion_date       completion_end_date component_name
#  26                NaT                       NaT      Bike Lane
#  35                NaT                       NaT      Bike Lane
#  294               NaT                       NaT      Bike Lane
#  370               NaT 2022-04-01 05:00:00+00:00      Bike Lane
#  375               NaT                       NaT      Bike Lane
#  ...               ...                       ...            ...
#  12026             NaT 2019-10-01 05:00:00+00:00      Bike Lane
#  12029             NaT 2019-10-01 05:00:00+00:00      Bike Lane
#  12034             NaT 2020-08-01 05:00:00+00:00      Bike Lane
#  12104             NaT                       NaT      Bike Lane
#  12142             NaT 2024-06-01 05:00:00+00:00      Bike Lane
#
#  [1927 rows x 9 columns],
#  'Trail':        project_id  project_component_id  \
#  374           279               11523.0
#  376           279               11524.0
#  387           283               11528.0
#  459           315               11958.0
#  473           322                   NaN
#  ...           ...                   ...
#  11970        3457               12174.0
#  11975        3462               12184.0
#  11978        3466                4587.0
#  11993        3474               12259.0
#  12055        3490               12338.0
#
#                                                  geometry  \
#  374    {'type': 'MultiLineString', 'coordinates': [[[...
#  376    {'type': 'MultiLineString', 'coordinates': [[[...
#  387    {'type': 'MultiLineString', 'coordinates': [[[...
#  459    {'type': 'MultiLineString', 'coordinates': [[[...
#  473                                                 None
#  ...                                                  ...
#  11970  {'type': 'MultiLineString', 'coordinates': [[[...
#  11975  {'type': 'MultiLineString', 'coordinates': [[[...
#  11978  {'type': 'MultiLineString', 'coordinates': [[[...
#  11993  {'type': 'MultiLineString', 'coordinates': [[[...
#  12055  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  374    {'type': 'MultiLineString', 'coordinates': [[[...
#  376    {'type': 'MultiLineString', 'coordinates': [[[...
#  387    {'type': 'MultiLineString', 'coordinates': [[[...
#  459    {'type': 'MultiLineString', 'coordinates': [[[...
#  473                                                 None
#  ...                                                  ...
#  11970  {'type': 'MultiLineString', 'coordinates': [[[...
#  11975  {'type': 'MultiLineString', 'coordinates': [[[...
#  11978  {'type': 'MultiLineString', 'coordinates': [[[...
#  11993  {'type': 'MultiLineString', 'coordinates': [[[...
#  12055  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  374                           NaT                                   NaT
#  376                           NaT                                   NaT
#  387                           NaT             2025-04-19 05:00:00+00:00
#  459     2022-10-06 05:00:00+00:00                                   NaT
#  473                           NaT                                   NaT
#  ...                           ...                                   ...
#  11970                         NaT                                   NaT
#  11975                         NaT                                   NaT
#  11978                         NaT                                   NaT
#  11993   2019-08-18 05:00:00+00:00                                   NaT
#  12055   2020-08-01 05:00:00+00:00                                   NaT
#
#        completion_date       completion_end_date component_name
#  374               NaT                       NaT          Trail
#  376               NaT                       NaT          Trail
#  387               NaT                       NaT          Trail
#  459               NaT                       NaT          Trail
#  473               NaT                       NaT          Trail
#  ...               ...                       ...            ...
#  11970             NaT                       NaT          Trail
#  11975             NaT                       NaT          Trail
#  11978             NaT                       NaT          Trail
#  11993             NaT 2019-08-18 05:00:00+00:00          Trail
#  12055             NaT 2020-08-01 05:00:00+00:00          Trail
#
#  [1170 rows x 9 columns],
#  'Crossing_Island':        project_id  project_component_id  \
#  402           295                7946.0
#  403           295               12090.0
#  404           295               12087.0
#  406           295               12089.0
#  410           295               12182.0
#  ...           ...                   ...
#  12124        3533               12445.0
#  12125        3533               12444.0
#  12133        3535               12458.0
#  12143        3536               12461.0
#  12144        3536               12460.0
#
#                                                  geometry  \
#  402    {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  403    {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  404    {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  406    {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  410    {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  ...                                                  ...
#  12124  {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  12125  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  12133  {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  12143  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  12144  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#
#                                             line_geometry  \
#  402    {'type': 'LineString', 'coordinates': [[-97.70...
#  403    {'type': 'LineString', 'coordinates': [[-97.71...
#  404    {'type': 'LineString', 'coordinates': [[-97.70...
#  406    {'type': 'LineString', 'coordinates': [[-97.70...
#  410    {'type': 'LineString', 'coordinates': [[-97.71...
#  ...                                                  ...
#  12124  {'type': 'LineString', 'coordinates': [[-97.71...
#  12125  {'type': 'LineString', 'coordinates': [[-97.70...
#  12133  {'type': 'LineString', 'coordinates': [[-97.74...
#  12143  {'type': 'LineString', 'coordinates': [[-97.73...
#  12144  {'type': 'LineString', 'coordinates': [[-97.73...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  402                           NaT                                   NaT
#  403                           NaT                                   NaT
#  404                           NaT                                   NaT
#  406                           NaT                                   NaT
#  410                           NaT                                   NaT
#  ...                           ...                                   ...
#  12124                         NaT             2024-06-01 05:00:00+00:00
#  12125                         NaT             2024-06-01 05:00:00+00:00
#  12133   2024-06-01 05:00:00+00:00                                   NaT
#  12143                         NaT             2024-06-01 05:00:00+00:00
#  12144                         NaT             2024-06-01 05:00:00+00:00
#
#        completion_date       completion_end_date   component_name
#  402               NaT                       NaT  Crossing Island
#  403               NaT                       NaT  Crossing Island
#  404               NaT                       NaT  Crossing Island
#  406               NaT                       NaT  Crossing Island
#  410               NaT                       NaT  Crossing Island
#  ...               ...                       ...              ...
#  12124             NaT 2024-06-01 05:00:00+00:00  Crossing Island
#  12125             NaT 2024-06-01 05:00:00+00:00  Crossing Island
#  12133             NaT 2024-06-01 05:00:00+00:00  Crossing Island
#  12143             NaT 2024-06-01 05:00:00+00:00  Crossing Island
#  12144             NaT 2024-06-01 05:00:00+00:00  Crossing Island
#
#  [751 rows x 9 columns],
#  'Pedestrian':        project_id  project_component_id  \
#  796           549                 699.0
#  1133          813               10740.0
#  2010         1479                1957.0
#  2012         1479                   NaN
#  2031         1485               11919.0
#  ...           ...                   ...
#  11606        3342               11501.0
#  11862        3365               11956.0
#  11913        3411               12055.0
#  11968        3455               10748.0
#  12179        3565               12523.0
#
#                                                  geometry  \
#  796    {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  1133   {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  2010   {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  2012                                                None
#  2031   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  11606  {'type': 'MultiPoint', 'coordinates': [[-97.84...
#  11862  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  11913  {'type': 'MultiPoint', 'coordinates': [[-97.63...
#  11968  {'type': 'MultiPoint', 'coordinates': [[-97.68...
#  12179  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#
#                                             line_geometry  \
#  796    {'type': 'LineString', 'coordinates': [[-97.71...
#  1133   {'type': 'LineString', 'coordinates': [[-97.71...
#  2010   {'type': 'LineString', 'coordinates': [[-97.73...
#  2012                                                None
#  2031   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  11606  {'type': 'LineString', 'coordinates': [[-97.84...
#  11862  {'type': 'LineString', 'coordinates': [[-97.73...
#  11913  {'type': 'LineString', 'coordinates': [[-97.63...
#  11968  {'type': 'LineString', 'coordinates': [[-97.68...
#  12179  {'type': 'LineString', 'coordinates': [[-97.70...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  796                           NaT                                   NaT
#  1133                          NaT                                   NaT
#  2010    2015-04-22 05:00:00+00:00                                   NaT
#  2012    2015-04-22 05:00:00+00:00                                   NaT
#  2031    2020-08-07 05:00:00+00:00                                   NaT
#  ...                           ...                                   ...
#  11606   2023-05-30 05:00:00+00:00                                   NaT
#  11862   2024-01-30 06:00:00+00:00                                   NaT
#  11913                         NaT                                   NaT
#  11968                         NaT                                   NaT
#  12179                         NaT                                   NaT
#
#                  completion_date completion_end_date component_name
#  796                         NaT                 NaT     Pedestrian
#  1133                        NaT                 NaT     Pedestrian
#  2010                        NaT                 NaT     Pedestrian
#  2012                        NaT                 NaT     Pedestrian
#  2031                        NaT                 NaT     Pedestrian
#  ...                         ...                 ...            ...
#  11606 2023-05-30 05:00:00+00:00                 NaT     Pedestrian
#  11862                       NaT                 NaT     Pedestrian
#  11913                       NaT                 NaT     Pedestrian
#  11968                       NaT                 NaT     Pedestrian
#  12179                       NaT                 NaT     Pedestrian
#
#  [271 rows x 9 columns],
#  'Intersection':        project_id  project_component_id  \
#  13             12                 469.0
#  31             22                 471.0
#  33             22               10461.0
#  115           109               12078.0
#  315           261               11612.0
#  ...           ...                   ...
#  12030        3485               12301.0
#  12031        3486               12308.0
#  12056        3490               12349.0
#  12057        3490               12348.0
#  12058        3490               12336.0
#
#                                                  geometry  \
#  13     {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  31     {'type': 'MultiLineString', 'coordinates': [[[...
#  33     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  115    {'type': 'MultiPoint', 'coordinates': [[-97.76...
#  315    {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  ...                                                  ...
#  12030  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12031  {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  12056  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  12057  {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  12058  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#
#                                             line_geometry  \
#  13     {'type': 'MultiLineString', 'coordinates': [[[...
#  31     {'type': 'MultiLineString', 'coordinates': [[[...
#  33     {'type': 'LineString', 'coordinates': [[-97.77...
#  115    {'type': 'LineString', 'coordinates': [[-97.76...
#  315    {'type': 'LineString', 'coordinates': [[-97.74...
#  ...                                                  ...
#  12030  {'type': 'LineString', 'coordinates': [[-97.75...
#  12031  {'type': 'LineString', 'coordinates': [[-97.72...
#  12056  {'type': 'LineString', 'coordinates': [[-97.70...
#  12057  {'type': 'LineString', 'coordinates': [[-97.69...
#  12058  {'type': 'LineString', 'coordinates': [[-97.70...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  13      2022-10-10 05:00:00+00:00                                   NaT
#  31                            NaT                                   NaT
#  33                            NaT                                   NaT
#  115                           NaT                                   NaT
#  315                           NaT                                   NaT
#  ...                           ...                                   ...
#  12030   2019-10-01 05:00:00+00:00                                   NaT
#  12031   2020-08-01 05:00:00+00:00                                   NaT
#  12056   2020-08-01 05:00:00+00:00                                   NaT
#  12057   2020-08-01 05:00:00+00:00                                   NaT
#  12058   2020-08-01 05:00:00+00:00                                   NaT
#
#        completion_date       completion_end_date component_name
#  13                NaT 2022-12-30 06:00:00+00:00   Intersection
#  31                NaT                       NaT   Intersection
#  33                NaT                       NaT   Intersection
#  115               NaT                       NaT   Intersection
#  315               NaT                       NaT   Intersection
#  ...               ...                       ...            ...
#  12030             NaT 2019-10-01 05:00:00+00:00   Intersection
#  12031             NaT 2020-08-01 05:00:00+00:00   Intersection
#  12056             NaT 2020-08-01 05:00:00+00:00   Intersection
#  12057             NaT 2020-08-01 05:00:00+00:00   Intersection
#  12058             NaT 2020-08-01 05:00:00+00:00   Intersection
#
#  [739 rows x 9 columns],
#  'Sidewalk':        project_id  project_component_id  \
#  208           164                 173.0
#  210           165                 175.0
#  211           166                 176.0
#  218           169                 188.0
#  280           232               11885.0
#  ...           ...                   ...
#  12052        3490               12337.0
#  12137        3536               12465.0
#  12140        3536               12468.0
#  12141        3536               12524.0
#  12145        3536               12464.0
#
#                                                  geometry  \
#  208    {'type': 'MultiLineString', 'coordinates': [[[...
#  210    {'type': 'MultiLineString', 'coordinates': [[[...
#  211    {'type': 'MultiLineString', 'coordinates': [[[...
#  218    {'type': 'MultiLineString', 'coordinates': [[[...
#  280    {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  ...                                                  ...
#  12052  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  12137  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  12140  {'type': 'MultiLineString', 'coordinates': [[[...
#  12141  {'type': 'MultiLineString', 'coordinates': [[[...
#  12145  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#
#                                             line_geometry  \
#  208    {'type': 'MultiLineString', 'coordinates': [[[...
#  210    {'type': 'MultiLineString', 'coordinates': [[[...
#  211    {'type': 'MultiLineString', 'coordinates': [[[...
#  218    {'type': 'MultiLineString', 'coordinates': [[[...
#  280    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12052  {'type': 'LineString', 'coordinates': [[-97.70...
#  12137  {'type': 'LineString', 'coordinates': [[-97.73...
#  12140  {'type': 'MultiLineString', 'coordinates': [[[...
#  12141  {'type': 'MultiLineString', 'coordinates': [[[...
#  12145  {'type': 'LineString', 'coordinates': [[-97.73...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  208     2022-04-23 05:00:00+00:00                                   NaT
#  210                           NaT                                   NaT
#  211                           NaT                                   NaT
#  218     2022-03-25 05:00:00+00:00                                   NaT
#  280     2023-09-04 05:00:00+00:00                                   NaT
#  ...                           ...                                   ...
#  12052   2020-08-01 05:00:00+00:00                                   NaT
#  12137                         NaT             2024-06-01 05:00:00+00:00
#  12140                         NaT             2024-06-01 05:00:00+00:00
#  12141                         NaT             2024-06-01 05:00:00+00:00
#  12145                         NaT             2024-06-01 05:00:00+00:00
#
#        completion_date       completion_end_date component_name
#  208               NaT                       NaT       Sidewalk
#  210               NaT                       NaT       Sidewalk
#  211               NaT                       NaT       Sidewalk
#  218               NaT 2022-03-25 05:00:00+00:00       Sidewalk
#  280               NaT 2023-09-04 05:00:00+00:00       Sidewalk
#  ...               ...                       ...            ...
#  12052             NaT 2020-08-01 05:00:00+00:00       Sidewalk
#  12137             NaT 2024-06-01 05:00:00+00:00       Sidewalk
#  12140             NaT 2024-06-01 05:00:00+00:00       Sidewalk
#  12141             NaT 2024-06-01 05:00:00+00:00       Sidewalk
#  12145             NaT 2024-06-01 05:00:00+00:00       Sidewalk
#
#  [3252 rows x 9 columns],
#  'Signal':        project_id  project_component_id  \
#  0               1                   5.0
#  1               2                   6.0
#  2               3                   7.0
#  3               4                   8.0
#  4               5                   9.0
#  ...           ...                   ...
#  12085        3508               12382.0
#  12091        3511               12398.0
#  12101        3522               12413.0
#  12102        3523               12411.0
#  12103        3524               12412.0
#
#                                                  geometry  \
#  0      {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  1      {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  2      {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  3      {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  4      {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  ...                                                  ...
#  12085  {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  12091  {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  12101  {'type': 'MultiPoint', 'coordinates': [[-97.63...
#  12102  {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  12103  {'type': 'MultiPoint', 'coordinates': [[-97.72...
#
#                                             line_geometry  \
#  0      {'type': 'LineString', 'coordinates': [[-97.71...
#  1      {'type': 'LineString', 'coordinates': [[-97.73...
#  2      {'type': 'LineString', 'coordinates': [[-97.74...
#  3      {'type': 'LineString', 'coordinates': [[-97.72...
#  4      {'type': 'LineString', 'coordinates': [[-97.77...
#  ...                                                  ...
#  12085  {'type': 'LineString', 'coordinates': [[-97.70...
#  12091  {'type': 'LineString', 'coordinates': [[-97.77...
#  12101  {'type': 'LineString', 'coordinates': [[-97.63...
#  12102  {'type': 'LineString', 'coordinates': [[-97.74...
#  12103  {'type': 'LineString', 'coordinates': [[-97.72...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  0                             NaT                                   NaT
#  1                             NaT             2024-02-15 06:00:00+00:00
#  2                             NaT                                   NaT
#  3                             NaT             2022-02-10 06:00:00+00:00
#  4                             NaT                                   NaT
#  ...                           ...                                   ...
#  12085                         NaT                                   NaT
#  12091                         NaT             2023-11-01 05:00:00+00:00
#  12101                         NaT                                   NaT
#  12102                         NaT                                   NaT
#  12103                         NaT             2024-06-28 05:00:00+00:00
#
#        completion_date       completion_end_date component_name
#  0                 NaT                       NaT         Signal
#  1                 NaT                       NaT         Signal
#  2                 NaT                       NaT         Signal
#  3                 NaT 2022-10-28 05:00:00+00:00         Signal
#  4                 NaT                       NaT         Signal
#  ...               ...                       ...            ...
#  12085             NaT                       NaT         Signal
#  12091             NaT 2023-11-01 05:00:00+00:00         Signal
#  12101             NaT                       NaT         Signal
#  12102             NaT                       NaT         Signal
#  12103             NaT                       NaT         Signal
#
#  [953 rows x 9 columns],
#  'Crosswalk':        project_id  project_component_id  \
#  446           308               12390.0
#  463           316               12434.0
#  465           317               12439.0
#  705           429                 580.0
#  786           535                 698.0
#  ...           ...                   ...
#  12045        3489               12326.0
#  12046        3489               12327.0
#  12047        3489               12325.0
#  12131        3535               12459.0
#  12134        3535               12457.0
#
#                                                  geometry  \
#  446    {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  463    {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  465    {'type': 'MultiPoint', 'coordinates': [[-97.64...
#  705    {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  786    {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  ...                                                  ...
#  12045  {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  12046  {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  12047  {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  12131  {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  12134  {'type': 'MultiPoint', 'coordinates': [[-97.74...
#
#                                             line_geometry  \
#  446    {'type': 'LineString', 'coordinates': [[-97.71...
#  463    {'type': 'LineString', 'coordinates': [[-97.72...
#  465    {'type': 'LineString', 'coordinates': [[-97.64...
#  705    {'type': 'LineString', 'coordinates': [[-97.72...
#  786    {'type': 'LineString', 'coordinates': [[-97.74...
#  ...                                                  ...
#  12045  {'type': 'LineString', 'coordinates': [[-97.69...
#  12046  {'type': 'LineString', 'coordinates': [[-97.69...
#  12047  {'type': 'LineString', 'coordinates': [[-97.69...
#  12131  {'type': 'LineString', 'coordinates': [[-97.74...
#  12134  {'type': 'LineString', 'coordinates': [[-97.74...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  446     2022-10-04 05:00:00+00:00                                   NaT
#  463                           NaT             2024-05-01 05:00:00+00:00
#  465                           NaT             2024-06-01 05:00:00+00:00
#  705                           NaT                                   NaT
#  786                           NaT                                   NaT
#  ...                           ...                                   ...
#  12045   2018-05-01 05:00:00+00:00                                   NaT
#  12046   2018-05-01 05:00:00+00:00                                   NaT
#  12047   2018-05-01 05:00:00+00:00                                   NaT
#  12131   2024-06-01 05:00:00+00:00                                   NaT
#  12134   2024-06-01 05:00:00+00:00                                   NaT
#
#        completion_date       completion_end_date component_name
#  446               NaT 2023-11-01 05:00:00+00:00      Crosswalk
#  463               NaT 2024-05-01 05:00:00+00:00      Crosswalk
#  465               NaT 2024-06-01 05:00:00+00:00      Crosswalk
#  705               NaT                       NaT      Crosswalk
#  786               NaT                       NaT      Crosswalk
#  ...               ...                       ...            ...
#  12045             NaT 2018-05-01 05:00:00+00:00      Crosswalk
#  12046             NaT 2018-05-01 05:00:00+00:00      Crosswalk
#  12047             NaT 2018-05-01 05:00:00+00:00      Crosswalk
#  12131             NaT 2024-06-01 05:00:00+00:00      Crosswalk
#  12134             NaT 2024-06-01 05:00:00+00:00      Crosswalk
#
#  [1102 rows x 9 columns],
#  'Project_Extent___Generic':        project_id  project_component_id  \
#  25             22               10464.0
#  30             22               10462.0
#  278           232                 321.0
#  282           233               11529.0
#  290           242                 387.0
#  ...           ...                   ...
#  12174        3560               12516.0
#  12175        3561               12517.0
#  12176        3562               12518.0
#  12177        3563               12519.0
#  12178        3564               12520.0
#
#                                                  geometry  \
#  25     {'type': 'MultiLineString', 'coordinates': [[[...
#  30     {'type': 'MultiLineString', 'coordinates': [[[...
#  278    {'type': 'MultiLineString', 'coordinates': [[[...
#  282    {'type': 'MultiLineString', 'coordinates': [[[...
#  290    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12174  {'type': 'MultiLineString', 'coordinates': [[[...
#  12175  {'type': 'MultiLineString', 'coordinates': [[[...
#  12176  {'type': 'MultiLineString', 'coordinates': [[[...
#  12177  {'type': 'MultiLineString', 'coordinates': [[[...
#  12178  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  25     {'type': 'MultiLineString', 'coordinates': [[[...
#  30     {'type': 'MultiLineString', 'coordinates': [[[...
#  278    {'type': 'MultiLineString', 'coordinates': [[[...
#  282    {'type': 'MultiLineString', 'coordinates': [[[...
#  290    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12174  {'type': 'MultiLineString', 'coordinates': [[[...
#  12175  {'type': 'MultiLineString', 'coordinates': [[[...
#  12176  {'type': 'MultiLineString', 'coordinates': [[[...
#  12177  {'type': 'MultiLineString', 'coordinates': [[[...
#  12178  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  25                            NaT                                   NaT
#  30                            NaT                                   NaT
#  278     2023-09-04 05:00:00+00:00                                   NaT
#  282                           NaT                                   NaT
#  290                           NaT                                   NaT
#  ...                           ...                                   ...
#  12174                         NaT                                   NaT
#  12175                         NaT                                   NaT
#  12176                         NaT                                   NaT
#  12177                         NaT                                   NaT
#  12178                         NaT                                   NaT
#
#        completion_date       completion_end_date            component_name
#  25                NaT                       NaT  Project Extent - Generic
#  30                NaT                       NaT  Project Extent - Generic
#  278               NaT 2023-09-04 05:00:00+00:00  Project Extent - Generic
#  282               NaT                       NaT  Project Extent - Generic
#  290               NaT                       NaT  Project Extent - Generic
#  ...               ...                       ...                       ...
#  12174             NaT                       NaT  Project Extent - Generic
#  12175             NaT                       NaT  Project Extent - Generic
#  12176             NaT                       NaT  Project Extent - Generic
#  12177             NaT                       NaT  Project Extent - Generic
#  12178             NaT                       NaT  Project Extent - Generic
#
#  [481 rows x 9 columns],
#  'Transit':        project_id  project_component_id  \
#  23             22               10469.0
#  27             22               10467.0
#  28             22               10470.0
#  29             22               10466.0
#  32             22               10471.0
#  ...           ...                   ...
#  12149        3538               12480.0
#  12150        3538               12484.0
#  12151        3538               12485.0
#  12153        3540               12522.0
#  12155        3540               12521.0
#
#                                                  geometry  \
#  23     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  27     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  28     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  29     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  32     {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  ...                                                  ...
#  12149  {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  12150  {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  12151  {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  12153  {'type': 'MultiLineString', 'coordinates': [[[...
#  12155  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  23     {'type': 'LineString', 'coordinates': [[-97.77...
#  27     {'type': 'LineString', 'coordinates': [[-97.77...
#  28     {'type': 'LineString', 'coordinates': [[-97.77...
#  29     {'type': 'LineString', 'coordinates': [[-97.77...
#  32     {'type': 'LineString', 'coordinates': [[-97.77...
#  ...                                                  ...
#  12149  {'type': 'LineString', 'coordinates': [[-97.77...
#  12150  {'type': 'LineString', 'coordinates': [[-97.77...
#  12151  {'type': 'LineString', 'coordinates': [[-97.77...
#  12153  {'type': 'MultiLineString', 'coordinates': [[[...
#  12155  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  23                            NaT                                   NaT
#  27                            NaT                                   NaT
#  28                            NaT                                   NaT
#  29                            NaT                                   NaT
#  32                            NaT                                   NaT
#  ...                           ...                                   ...
#  12149                         NaT                                   NaT
#  12150                         NaT                                   NaT
#  12151                         NaT                                   NaT
#  12153                         NaT                                   NaT
#  12155                         NaT                                   NaT
#
#        completion_date completion_end_date component_name
#  23                NaT                 NaT        Transit
#  27                NaT                 NaT        Transit
#  28                NaT                 NaT        Transit
#  29                NaT                 NaT        Transit
#  32                NaT                 NaT        Transit
#  ...               ...                 ...            ...
#  12149             NaT                 NaT        Transit
#  12150             NaT                 NaT        Transit
#  12151             NaT                 NaT        Transit
#  12153             NaT                 NaT        Transit
#  12155             NaT                 NaT        Transit
#
#  [287 rows x 9 columns],
#  'Speed_Management':        project_id  project_component_id  \
#  286           237               11884.0
#  320           261                 310.0
#  368           277                 337.0
#  2479         1749                2423.0
#  2623         1811               12108.0
#  ...           ...                   ...
#  10542        3058               10460.0
#  10908        3101                6070.0
#  11418        3248                   NaN
#  11925        3418               12072.0
#  11927        3418               12071.0
#
#                                                  geometry  \
#  286    {'type': 'MultiLineString', 'coordinates': [[[...
#  320    {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  368    {'type': 'MultiLineString', 'coordinates': [[[...
#  2479   {'type': 'MultiPoint', 'coordinates': [[-97.64...
#  2623   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  10542  {'type': 'MultiLineString', 'coordinates': [[[...
#  10908  {'type': 'MultiLineString', 'coordinates': [[[...
#  11418                                               None
#  11925  {'type': 'MultiPoint', 'coordinates': [[-97.68...
#  11927  {'type': 'MultiPoint', 'coordinates': [[-97.68...
#
#                                             line_geometry  \
#  286    {'type': 'MultiLineString', 'coordinates': [[[...
#  320    {'type': 'LineString', 'coordinates': [[-97.74...
#  368    {'type': 'MultiLineString', 'coordinates': [[[...
#  2479   {'type': 'LineString', 'coordinates': [[-97.64...
#  2623   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  10542  {'type': 'MultiLineString', 'coordinates': [[[...
#  10908  {'type': 'MultiLineString', 'coordinates': [[[...
#  11418                                               None
#  11925  {'type': 'LineString', 'coordinates': [[-97.68...
#  11927  {'type': 'LineString', 'coordinates': [[-97.68...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  286                           NaT                                   NaT
#  320                           NaT                                   NaT
#  368                           NaT                                   NaT
#  2479                          NaT                                   NaT
#  2623    2021-07-17 05:00:00+00:00                                   NaT
#  ...                           ...                                   ...
#  10542   2021-06-10 05:00:00+00:00                                   NaT
#  10908                         NaT                                   NaT
#  11418                         NaT                                   NaT
#  11925                         NaT                                   NaT
#  11927                         NaT                                   NaT
#
#        completion_date completion_end_date    component_name
#  286               NaT                 NaT  Speed Management
#  320               NaT                 NaT  Speed Management
#  368               NaT                 NaT  Speed Management
#  2479              NaT                 NaT  Speed Management
#  2623              NaT                 NaT  Speed Management
#  ...               ...                 ...               ...
#  10542             NaT                 NaT  Speed Management
#  10908             NaT                 NaT  Speed Management
#  11418             NaT                 NaT  Speed Management
#  11925             NaT                 NaT  Speed Management
#  11927             NaT                 NaT  Speed Management
#
#  [196 rows x 9 columns],
#  'Pavement_Marking':        project_id  project_component_id  \
#  826           587               12048.0
#  843           599                 799.0
#  888           643                 844.0
#  909           656                 865.0
#  933           679                 890.0
#  ...           ...                   ...
#  12012        3481               12289.0
#  12018        3483               12294.0
#  12023        3484               12299.0
#  12028        3485               12306.0
#  12033        3486               12309.0
#
#                                                  geometry  \
#  826    {'type': 'MultiPoint', 'coordinates': [[-97.70...
#  843    {'type': 'MultiLineString', 'coordinates': [[[...
#  888    {'type': 'MultiLineString', 'coordinates': [[[...
#  909    {'type': 'MultiLineString', 'coordinates': [[[...
#  933    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12012  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12018  {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  12023  {'type': 'MultiPoint', 'coordinates': [[-97.66...
#  12028  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12033  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  826    {'type': 'LineString', 'coordinates': [[-97.70...
#  843    {'type': 'MultiLineString', 'coordinates': [[[...
#  888    {'type': 'MultiLineString', 'coordinates': [[[...
#  909    {'type': 'MultiLineString', 'coordinates': [[[...
#  933    {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12012  {'type': 'LineString', 'coordinates': [[-97.75...
#  12018  {'type': 'LineString', 'coordinates': [[-97.71...
#  12023  {'type': 'LineString', 'coordinates': [[-97.66...
#  12028  {'type': 'LineString', 'coordinates': [[-97.75...
#  12033  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  826     2024-04-16 05:00:00+00:00                                   NaT
#  843                           NaT             2015-01-01 06:00:00+00:00
#  888     2008-10-01 05:00:00+00:00                                   NaT
#  909     2019-10-30 05:00:00+00:00                                   NaT
#  933     2008-10-01 05:00:00+00:00                                   NaT
#  ...                           ...                                   ...
#  12012                         NaT             2019-01-14 06:00:00+00:00
#  12018   2018-05-01 05:00:00+00:00                                   NaT
#  12023   2020-12-01 06:00:00+00:00                                   NaT
#  12028   2019-10-01 05:00:00+00:00                                   NaT
#  12033   2020-08-01 05:00:00+00:00                                   NaT
#
#        completion_date       completion_end_date    component_name
#  826               NaT                       NaT  Pavement Marking
#  843               NaT                       NaT  Pavement Marking
#  888               NaT                       NaT  Pavement Marking
#  909               NaT                       NaT  Pavement Marking
#  933               NaT                       NaT  Pavement Marking
#  ...               ...                       ...               ...
#  12012             NaT 2019-01-14 06:00:00+00:00  Pavement Marking
#  12018             NaT 2018-05-01 05:00:00+00:00  Pavement Marking
#  12023             NaT 2020-12-01 06:00:00+00:00  Pavement Marking
#  12028             NaT 2019-10-01 05:00:00+00:00  Pavement Marking
#  12033             NaT 2020-08-01 05:00:00+00:00  Pavement Marking
#
#  [89 rows x 9 columns],
#  'Signage':        project_id  project_component_id  \
#  857           613                 813.0
#  927           674                 884.0
#  1075          765                   NaN
#  1076          766                1033.0
#  1094          776                1051.0
#  ...           ...                   ...
#  12061        3492               12354.0
#  12062        3492               12352.0
#  12063        3492               12356.0
#  12064        3492               12355.0
#  12065        3492               12353.0
#
#                                                  geometry  \
#  857    {'type': 'MultiLineString', 'coordinates': [[[...
#  927    {'type': 'MultiLineString', 'coordinates': [[[...
#  1075                                                None
#  1076   {'type': 'MultiLineString', 'coordinates': [[[...
#  1094   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12061  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12062  {'type': 'MultiPoint', 'coordinates': [[-97.76...
#  12063  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12064  {'type': 'MultiPoint', 'coordinates': [[-97.75...
#  12065  {'type': 'MultiPoint', 'coordinates': [[-97.76...
#
#                                             line_geometry  \
#  857    {'type': 'MultiLineString', 'coordinates': [[[...
#  927    {'type': 'MultiLineString', 'coordinates': [[[...
#  1075                                                None
#  1076   {'type': 'MultiLineString', 'coordinates': [[[...
#  1094   {'type': 'MultiLineString', 'coordinates': [[[...
#  ...                                                  ...
#  12061  {'type': 'LineString', 'coordinates': [[-97.75...
#  12062  {'type': 'LineString', 'coordinates': [[-97.76...
#  12063  {'type': 'LineString', 'coordinates': [[-97.75...
#  12064  {'type': 'LineString', 'coordinates': [[-97.75...
#  12065  {'type': 'LineString', 'coordinates': [[-97.76...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  857     2008-01-01 06:00:00+00:00                                   NaT
#  927                           NaT             2009-06-01 05:00:00+00:00
#  1075    2009-05-07 05:00:00+00:00                                   NaT
#  1076    2009-05-07 05:00:00+00:00                                   NaT
#  1094    2010-04-19 05:00:00+00:00                                   NaT
#  ...                           ...                                   ...
#  12061   2020-02-01 06:00:00+00:00                                   NaT
#  12062   2020-02-01 06:00:00+00:00                                   NaT
#  12063   2020-02-01 06:00:00+00:00                                   NaT
#  12064   2020-02-01 06:00:00+00:00                                   NaT
# ...
#  4787         2673                4659.0
#  4867         2676                4731.0
#  5037         2680                4908.0
#  5040         2680                4915.0
#  5080         2680                4912.0
#  5112         2680                   NaN
#  5136         2681                4996.0
#  5269         2684                5169.0
#  5309         2685                5176.0
#  5335         2686                5210.0
#  5419         2689                5290.0
#  5457         2690                5326.0
#  5658         2693                5482.0
#  5816         2695                5644.0
#  5879         2697                5739.0
#  6069         2704                5913.0
#  6181         2707                6064.0
#  6193         2707                6071.0
#  6344         2712                6204.0
#  6477         2716                6349.0
#  6548         2717                6408.0
#  6635         2719                6518.0
#  6721         2722                6604.0
#  6834         2724                6692.0
#  6990         2727                6865.0
#  7049         2728                6899.0
#  7358         2733                7272.0
#  7442         2735                7297.0
#  8244         2753                8143.0
#  8602         2765                8464.0
#  9166         2780                9085.0
#  9281         2782                9129.0
#  9428         2784                9332.0
#  9448         2785                9341.0
#  10170        2873                   NaN
#  10991        3145                   NaN
#  11866        3369               11967.0
#  11990        3474               12257.0
#
#                                                  geometry  \
#  466    {'type': 'MultiLineString', 'coordinates': [[[...
#  497    {'type': 'MultiLineString', 'coordinates': [[[...
#  501    {'type': 'MultiLineString', 'coordinates': [[[...
#  1600   {'type': 'MultiLineString', 'coordinates': [[[...
#  2454   {'type': 'MultiLineString', 'coordinates': [[[...
#  3121   {'type': 'MultiLineString', 'coordinates': [[[...
#  3130   {'type': 'MultiLineString', 'coordinates': [[[...
#  4111   {'type': 'MultiLineString', 'coordinates': [[[...
#  4264   {'type': 'MultiLineString', 'coordinates': [[[...
#  4298   {'type': 'MultiLineString', 'coordinates': [[[...
#  4333   {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  4348   {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  4420   {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  4670   {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  4680   {'type': 'MultiPoint', 'coordinates': [[-97.72...
#  4787   {'type': 'MultiLineString', 'coordinates': [[[...
#  4867   {'type': 'MultiPoint', 'coordinates': [[-97.80...
#  5037   {'type': 'MultiLineString', 'coordinates': [[[...
#  5040   {'type': 'MultiLineString', 'coordinates': [[[...
#  5080   {'type': 'MultiLineString', 'coordinates': [[[...
#  5112                                                None
#  5136   {'type': 'MultiPoint', 'coordinates': [[-97.71...
#  5269   {'type': 'MultiPoint', 'coordinates': [[-97.81...
#  5309   {'type': 'MultiPoint', 'coordinates': [[-97.76...
#  5335   {'type': 'MultiLineString', 'coordinates': [[[...
#  5419   {'type': 'MultiPoint', 'coordinates': [[-97.66...
#  5457   {'type': 'MultiPoint', 'coordinates': [[-97.81...
#  5658   {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  5816   {'type': 'MultiPoint', 'coordinates': [[-97.76...
#  5879   {'type': 'MultiPoint', 'coordinates': [[-97.62...
#  6069   {'type': 'MultiPoint', 'coordinates': [[-97.78...
#  6181   {'type': 'MultiLineString', 'coordinates': [[[...
#  6193   {'type': 'MultiLineString', 'coordinates': [[[...
#  6344   {'type': 'MultiPoint', 'coordinates': [[-97.80...
#  6477   {'type': 'MultiPoint', 'coordinates': [[-97.68...
#  6548   {'type': 'MultiLineString', 'coordinates': [[[...
#  6635   {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  6721   {'type': 'MultiLineString', 'coordinates': [[[...
#  6834   {'type': 'MultiPoint', 'coordinates': [[-97.78...
#  6990   {'type': 'MultiLineString', 'coordinates': [[[...
#  7049   {'type': 'MultiPoint', 'coordinates': [[-97.83...
#  7358   {'type': 'MultiLineString', 'coordinates': [[[...
#  7442   {'type': 'MultiPoint', 'coordinates': [[-97.73...
#  8244   {'type': 'MultiLineString', 'coordinates': [[[...
#  8602   {'type': 'MultiPoint', 'coordinates': [[-97.77...
#  9166   {'type': 'MultiLineString', 'coordinates': [[[...
#  9281   {'type': 'MultiPoint', 'coordinates': [[-97.74...
#  9428   {'type': 'MultiPoint', 'coordinates': [[-97.69...
#  9448   {'type': 'MultiPoint', 'coordinates': [[-97.68...
#  10170                                               None
#  10991                                               None
#  11866  {'type': 'MultiLineString', 'coordinates': [[[...
#  11990  {'type': 'MultiLineString', 'coordinates': [[[...
#
#                                             line_geometry  \
#  466    {'type': 'MultiLineString', 'coordinates': [[[...
#  497    {'type': 'MultiLineString', 'coordinates': [[[...
#  501    {'type': 'MultiLineString', 'coordinates': [[[...
#  1600   {'type': 'MultiLineString', 'coordinates': [[[...
#  2454   {'type': 'MultiLineString', 'coordinates': [[[...
#  3121   {'type': 'MultiLineString', 'coordinates': [[[...
#  3130   {'type': 'MultiLineString', 'coordinates': [[[...
#  4111   {'type': 'MultiLineString', 'coordinates': [[[...
#  4264   {'type': 'MultiLineString', 'coordinates': [[[...
#  4298   {'type': 'MultiLineString', 'coordinates': [[[...
#  4333   {'type': 'LineString', 'coordinates': [[-97.69...
#  4348   {'type': 'LineString', 'coordinates': [[-97.69...
#  4420   {'type': 'LineString', 'coordinates': [[-97.71...
#  4670   {'type': 'LineString', 'coordinates': [[-97.72...
#  4680   {'type': 'LineString', 'coordinates': [[-97.72...
#  4787   {'type': 'MultiLineString', 'coordinates': [[[...
#  4867   {'type': 'LineString', 'coordinates': [[-97.80...
#  5037   {'type': 'MultiLineString', 'coordinates': [[[...
#  5040   {'type': 'MultiLineString', 'coordinates': [[[...
#  5080   {'type': 'MultiLineString', 'coordinates': [[[...
#  5112                                                None
#  5136   {'type': 'LineString', 'coordinates': [[-97.71...
#  5269   {'type': 'LineString', 'coordinates': [[-97.81...
#  5309   {'type': 'LineString', 'coordinates': [[-97.76...
#  5335   {'type': 'MultiLineString', 'coordinates': [[[...
#  5419   {'type': 'LineString', 'coordinates': [[-97.66...
#  5457   {'type': 'LineString', 'coordinates': [[-97.81...
#  5658   {'type': 'LineString', 'coordinates': [[-97.74...
#  5816   {'type': 'LineString', 'coordinates': [[-97.76...
#  5879   {'type': 'LineString', 'coordinates': [[-97.62...
#  6069   {'type': 'LineString', 'coordinates': [[-97.78...
#  6181   {'type': 'MultiLineString', 'coordinates': [[[...
#  6193   {'type': 'MultiLineString', 'coordinates': [[[...
#  6344   {'type': 'LineString', 'coordinates': [[-97.80...
#  6477   {'type': 'LineString', 'coordinates': [[-97.68...
#  6548   {'type': 'MultiLineString', 'coordinates': [[[...
#  6635   {'type': 'LineString', 'coordinates': [[-97.74...
#  6721   {'type': 'MultiLineString', 'coordinates': [[[...
#  6834   {'type': 'LineString', 'coordinates': [[-97.78...
#  6990   {'type': 'MultiLineString', 'coordinates': [[[...
#  7049   {'type': 'LineString', 'coordinates': [[-97.83...
#  7358   {'type': 'MultiLineString', 'coordinates': [[[...
#  7442   {'type': 'LineString', 'coordinates': [[-97.73...
#  8244   {'type': 'MultiLineString', 'coordinates': [[[...
#  8602   {'type': 'LineString', 'coordinates': [[-97.77...
#  9166   {'type': 'MultiLineString', 'coordinates': [[[...
#  9281   {'type': 'LineString', 'coordinates': [[-97.74...
#  9428   {'type': 'LineString', 'coordinates': [[-97.69...
#  9448   {'type': 'LineString', 'coordinates': [[-97.68...
#  10170                                               None
#  10991                                               None
#  11866  {'type': 'MultiLineString', 'coordinates': [[[...
#  11990  {'type': 'MultiLineString', 'coordinates': [[[...
#
#        substantial_completion_date substantial_completion_date_estimated  \
#  466                           NaT             2024-06-01 05:00:00+00:00
#  497                           NaT                                   NaT
#  501                           NaT                                   NaT
#  1600    2022-05-06 05:00:00+00:00                                   NaT
#  2454                          NaT                                   NaT
#  3121    2018-08-01 05:00:00+00:00                                   NaT
#  3130    2018-08-01 05:00:00+00:00                                   NaT
#  4111    2020-12-10 06:00:00+00:00                                   NaT
#  4264                          NaT                                   NaT
#  4298                          NaT                                   NaT
#  4333                          NaT                                   NaT
#  4348                          NaT                                   NaT
#  4420                          NaT                                   NaT
#  4670                          NaT                                   NaT
#  4680                          NaT                                   NaT
#  4787                          NaT                                   NaT
#  4867                          NaT                                   NaT
#  5037                          NaT                                   NaT
#  5040                          NaT                                   NaT
#  5080                          NaT                                   NaT
#  5112                          NaT                                   NaT
#  5136                          NaT                                   NaT
#  5269                          NaT                                   NaT
#  5309                          NaT                                   NaT
#  5335                          NaT                                   NaT
#  5419                          NaT                                   NaT
#  5457                          NaT                                   NaT
#  5658                          NaT                                   NaT
#  5816                          NaT                                   NaT
#  5879                          NaT                                   NaT
#  6069                          NaT                                   NaT
#  6181                          NaT                                   NaT
#  6193                          NaT                                   NaT
#  6344                          NaT                                   NaT
#  6477                          NaT                                   NaT
#  6548                          NaT                                   NaT
#  6635                          NaT                                   NaT
#  6721                          NaT                                   NaT
#  6834                          NaT                                   NaT
#  6990                          NaT                                   NaT
#  7049                          NaT                                   NaT
#  7358                          NaT                                   NaT
#  7442                          NaT                                   NaT
#  8244                          NaT                                   NaT
#  8602                          NaT                                   NaT
#  9166                          NaT                                   NaT
#  9281                          NaT                                   NaT
#  9428                          NaT                                   NaT
#  9448                          NaT                                   NaT
#  10170                         NaT                                   NaT
#  10991                         NaT                                   NaT
#  11866                         NaT                                   NaT
#  11990   2019-08-18 05:00:00+00:00                                   NaT
#
#        completion_date       completion_end_date  component_name
#  466               NaT 2024-06-01 05:00:00+00:00  Access Control
#  497               NaT                       NaT  Access Control
#  501               NaT                       NaT  Access Control
#  1600              NaT                       NaT  Access Control
#  2454              NaT                       NaT  Access Control
#  3121              NaT                       NaT  Access Control
#  3130              NaT                       NaT  Access Control
#  4111              NaT                       NaT  Access Control
#  4264              NaT                       NaT  Access Control
#  4298              NaT                       NaT  Access Control
#  4333              NaT                       NaT  Access Control
#  4348              NaT                       NaT  Access Control
#  4420              NaT                       NaT  Access Control
#  4670              NaT                       NaT  Access Control
#  4680              NaT                       NaT  Access Control
#  4787              NaT                       NaT  Access Control
#  4867              NaT                       NaT  Access Control
#  5037              NaT                       NaT  Access Control
#  5040              NaT                       NaT  Access Control
#  5080              NaT                       NaT  Access Control
#  5112              NaT                       NaT  Access Control
#  5136              NaT                       NaT  Access Control
#  5269              NaT                       NaT  Access Control
#  5309              NaT                       NaT  Access Control
#  5335              NaT                       NaT  Access Control
#  5419              NaT                       NaT  Access Control
#  5457              NaT                       NaT  Access Control
#  5658              NaT                       NaT  Access Control
#  5816              NaT                       NaT  Access Control
#  5879              NaT                       NaT  Access Control
#  6069              NaT                       NaT  Access Control
#  6181              NaT                       NaT  Access Control
#  6193              NaT                       NaT  Access Control
#  6344              NaT                       NaT  Access Control
#  6477              NaT                       NaT  Access Control
#  6548              NaT                       NaT  Access Control
#  6635              NaT                       NaT  Access Control
#  6721              NaT                       NaT  Access Control
#  6834              NaT                       NaT  Access Control
#  6990              NaT                       NaT  Access Control
#  7049              NaT                       NaT  Access Control
#  7358              NaT                       NaT  Access Control
#  7442              NaT                       NaT  Access Control
#  8244              NaT                       NaT  Access Control
#  8602              NaT                       NaT  Access Control
#  9166              NaT                       NaT  Access Control
#  9281              NaT                       NaT  Access Control
#  9428              NaT                       NaT  Access Control
#  9448              NaT                       NaT  Access Control
#  10170             NaT                       NaT  Access Control
#  10991             NaT                       NaT  Access Control
#  11866             NaT                       NaT  Access Control
#  11990             NaT 2019-08-18 05:00:00+00:00  Access Control  }

# %%
# Perform the spatial join
crashes_near_projects = gpd.sjoin(gdf_vz, buffered_moped_gdf, how='inner')

# Creating a unique ID column
crashes_near_projects['crash_project_component_id'] = crashes_near_projects['crash_id'].astype(str) + "-" + crashes_near_projects['project_id'].astype(str) + "-" + crashes_near_projects['project_component_id'].astype(str)
