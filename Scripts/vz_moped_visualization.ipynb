# %%
# Package imports
import pandas as pd
import geopandas as gpd
import plotly.express as px  # (version 4.7.0 or higher)
import plotly.graph_objects as go
from dash import Dash, dcc, html, Input, Output  # pip install dash (version 2.0.0 or higher)
import dash_bootstrap_components as dbc

# %%
# Data imports
vz_moped = pd.read_csv('../Output/annualized_statistics.csv')

# %%
vz_moped
# Out:
#       moped_component_id component_name              component_name_full  \
# 0                      2         Signal                 Signal - Traffic
# 1                      3         Signal                 Signal - Traffic
# 2                      4   Intersection       Intersection - Improvement
# 3                      5         Signal                 Signal - Traffic
# 4                      7         Signal                 Signal - Traffic
# ...                  ...            ...                              ...
# 2062                2676      Crosswalk          Crosswalk - Continental
# 2063                2677      Crosswalk          Crosswalk - Continental
# 2064                2679      Crosswalk          Crosswalk - Continental
# 2065                2691   Intersection       Intersection - Improvement
# 2066                2732          Trail  Trail - Shared Use Path (Paved)
#
#             component_subtype  component_work_types     type_name  \
# 0                     Traffic          Modification  Signal - Mod
# 1                     Traffic          Modification  Signal - Mod
# 2                 Improvement                   NaN  Signal - Mod
# 3                     Traffic          Modification  Signal - Mod
# 4                     Traffic          Modification  Signal - Mod
# ...                       ...                   ...           ...
# 2062              Continental  Maintenance / Repair           NaN
# 2063              Continental  Maintenance / Repair           NaN
# 2064              Continental  Maintenance / Repair           NaN
# 2065              Improvement                   New           NaN
# 2066  Shared Use Path (Paved)                   NaN           NaN
#
#                                           line_geometry  \
# 0     LINESTRING (621756.8366993731 3349129.94356965...
# 1     LINESTRING (621800.8777623806 3349002.52492784...
# 2     MULTILINESTRING ((621833.0059268889 3349106.73...
# 3     LINESTRING (621722.7430791555 3349029.36478667...
# 4     LINESTRING (617652.5950659687 3350801.66808639...
# ...                                                 ...
# 2062  LINESTRING (623842.7010678828 3347520.43842898...
# 2063  LINESTRING (623843.3851088278 3347522.22627086...
# 2064  LINESTRING (623843.9510698958 3347520.92963792...
# 2065  LINESTRING (622267.3579816862 3353662.73915396...
# 2066  MULTILINESTRING ((620184.5023216581 3350029.59...
#
#      substantial_completion_date  pre_annualized_crash_rate  \
# 0      2022-10-10 05:00:00+00:00                   0.119537
# 1      2022-10-10 05:00:00+00:00                   0.167992
# 2      2022-10-10 05:00:00+00:00                   0.159788
# 3      2022-10-10 05:00:00+00:00                   0.157995
# 4      2024-02-20 06:00:00+00:00                   0.136192
# ...                          ...                        ...
# 2062   2018-05-01 05:00:00+00:00                        NaN
# 2063   2018-05-01 05:00:00+00:00                        NaN
# 2064   2018-05-01 05:00:00+00:00                        NaN
# 2065   2020-08-01 05:00:00+00:00                        NaN
# 2066   1970-01-01 06:00:00+00:00                        NaN
#
#       post_annualized_crash_rate  ...  delta_fatal_crash_rate  \
# 0                            NaN  ...                     NaN
# 1                            NaN  ...                     NaN
# 2                       0.736701  ...                     0.0
# 3                       0.736701  ...                     0.0
# 4                            NaN  ...                     NaN
# ...                          ...  ...                     ...
# 2062                    0.468034  ...                     NaN
# 2063                    0.513864  ...                     NaN
# 2064                    0.513864  ...                     NaN
# 2065                    0.346935  ...                     NaN
# 2066                    0.021089  ...                     NaN
#
#       pre_annualized_injury_rate  post_annualized_injury_rate  \
# 0                       0.039846                          NaN
# 1                       0.111995                          NaN
# 2                       0.036315                     0.736701
# 3                       0.022571                     0.736701
# 4                       0.085120                          NaN
# ...                          ...                          ...
# 2062                         NaN                     0.374427
# 2063                         NaN                     0.385398
# 2064                         NaN                     0.385398
# 2065                         NaN                     0.000000
# 2066                         NaN                     0.010400
#
#       delta_injury_rate  pre_annualized_death_rate  \
# 0                   NaN                        0.0
# 1                   NaN                        0.0
# 2              0.700385                        0.0
# 3              0.714130                        0.0
# 4                   NaN                        0.0
# ...                 ...                        ...
# 2062                NaN                        NaN
# 2063                NaN                        NaN
# 2064                NaN                        NaN
# 2065                NaN                        NaN
# 2066                NaN                        NaN
#
#       post_annualized_death_rate  delta_death_rate  pre_annualized_cost  \
# 0                            NaN               NaN         17412.542784
# 1                            NaN               NaN        156960.694506
# 2                            0.0               0.0         45437.828003
# 3                            0.0               0.0         30583.347709
# 4                            NaN               NaN         31988.103006
# ...                          ...               ...                  ...
# 2062                         0.0               NaN                  NaN
# 2063                         0.0               NaN                  NaN
# 2064                         0.0               NaN                  NaN
# 2065                         0.0               NaN                  NaN
# 2066                         0.0               NaN                  NaN
#
#       post_annualized_cost  delta_comp_cost
# 0                      NaN              NaN
# 1                      NaN              NaN
# 2            171651.231196    126213.403193
# 3            171651.231196    141067.883487
# 4                      NaN              NaN
# ...                    ...              ...
# 2062         130207.118221              NaN
# 2063         142211.765051              NaN
# 2064         142211.765051              NaN
# 2065          35387.343175              NaN
# 2066           5939.300363              NaN
#
# [2067 rows x 23 columns]

# %% [markdown]
# ### Building Dash components

# %%
app = Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# %% [markdown]
# ### Building dash layout

# %%
app.layout = [html.Div(children='Hello World')]

# %% [markdown]
# ### Building application call back

# %% [markdown]
# ### Running app

# %%
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
