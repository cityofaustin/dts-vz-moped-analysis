# %%
import psycopg2
import json
import pandas as pd
import geopandas as gpd
from shapely.geometry import shape
from shapely.geometry import LineString, MultiLineString
import matplotlib.pyplot as plt

from config import DB_VISION_ZERO, DB_MOPED
from helper import dict_factory, to_json_list

# %%
def get_data(query, cursor):
    """
    Get data from database
    """
    cursor.execute(query)
    data = cursor.fetchall()
    field_names = [i[0] for i in cursor.description]
    df = pd.DataFrame(data, columns=field_names)

    return df

conn_vz = psycopg2.connect(
    dbname = DB_VISION_ZERO['dbname'],
    user = DB_VISION_ZERO["user"],
    host = DB_VISION_ZERO["host"],
    password = DB_VISION_ZERO["password"],
    port=5432
)

conn_moped = psycopg2.connect(
    dbname = DB_MOPED["dbname"],
    user = DB_MOPED["user"],
    host = DB_MOPED["host"],
    password = DB_MOPED["password"],
    port = 5432
)

cursor_vz = conn_vz.cursor()
cursor_moped = conn_moped.cursor()

# %% [markdown]
# # Moped processing

# %%
# Creating moped dataframe
QUERY_MOPED = """SELECT project_id, project_component_id, geometry, 
line_geometry, substantial_completion_date, 
substantial_completion_date_estimated, completion_date, completion_end_date
FROM component_arcgis_online_view"""

# Creating moped dataframe
df_moped = get_data(QUERY_MOPED, cursor_moped)
df_moped.to_csv('df_moped.csv')

# %%
# Data frame info
df_moped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12080 entries, 0 to 12079
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   project_id                             12080 non-null  int64
#  1   project_component_id                   11632 non-null  float64
#  2   geometry                               11632 non-null  object
#  3   line_geometry                          11632 non-null  object
#  4   substantial_completion_date            2851 non-null   datetime64[ns, UTC]
#  5   substantial_completion_date_estimated  348 non-null    datetime64[ns, UTC]
#  6   completion_date                        349 non-null    datetime64[ns, UTC]
#  7   completion_end_date                    213 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](4), float64(1), int64(1), object(2)
# memory usage: 755.1+ KB

# %%
# Dropping observations where completion end date is not present
df_moped_filter = df_moped.dropna(subset=['substantial_completion_date'])
df_moped_filter.head()
# Out:
#     project_id  project_component_id  \
# 10          12                 181.0
# 11          12                 183.0
# 12          12                 469.0
# 13          12                 182.0
# 14          12                  16.0
#
#                                              geometry  \
# 10  {'type': 'MultiPoint', 'coordinates': [[-97.73...
# 11  {'type': 'MultiPoint', 'coordinates': [[-97.73...
# 12  {'type': 'MultiPoint', 'coordinates': [[-97.73...
# 13  {'type': 'MultiPoint', 'coordinates': [[-97.73...
# 14  {'type': 'MultiPoint', 'coordinates': [[-97.73...
#
#                                         line_geometry  \
# 10  {'type': 'LineString', 'coordinates': [[-97.73...
# 11  {'type': 'LineString', 'coordinates': [[-97.73...
# 12  {'type': 'MultiLineString', 'coordinates': [[[...
# 13  {'type': 'LineString', 'coordinates': [[-97.73...
# 14  {'type': 'LineString', 'coordinates': [[-97.73...
#
#    substantial_completion_date substantial_completion_date_estimated  \
# 10   2022-10-10 05:00:00+00:00                                   NaT
# 11   2022-10-10 05:00:00+00:00                                   NaT
# 12   2022-10-10 05:00:00+00:00                                   NaT
# 13   2022-10-10 05:00:00+00:00                                   NaT
# 14   2022-10-10 05:00:00+00:00                                   NaT
#
#    completion_date       completion_end_date
# 10             NaT 2022-12-30 06:00:00+00:00
# 11             NaT 2022-12-30 06:00:00+00:00
# 12             NaT 2022-12-30 06:00:00+00:00
# 13             NaT 2022-12-30 06:00:00+00:00
# 14             NaT 2022-12-30 06:00:00+00:00

# %%
df_moped_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2851 entries, 10 to 12074
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   project_id                             2851 non-null   int64
#  1   project_component_id                   2668 non-null   float64
#  2   geometry                               2668 non-null   object
#  3   line_geometry                          2668 non-null   object
#  4   substantial_completion_date            2851 non-null   datetime64[ns, UTC]
#  5   substantial_completion_date_estimated  25 non-null     datetime64[ns, UTC]
#  6   completion_date                        349 non-null    datetime64[ns, UTC]
#  7   completion_end_date                    181 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](4), float64(1), int64(1), object(2)
# memory usage: 200.5+ KB

# %%
# Convert timestamp columns to string using .loc
timestamp_columns = ["substantial_completion_date",
                     "substantial_completion_date_estimated", 
                     "completion_date", 
                     "completion_end_date"]

for col in timestamp_columns:
    df_moped_filter.loc[:, col] = df_moped_filter[col].astype(str)

# Apply the geometry transformation using .loc
df_moped_filter.loc[:, "geometry"] = df_moped_filter["geometry"].apply(lambda x: shape(x) if x is not None else None)

# Create GeoDataFrame
gdf_moped = gpd.GeoDataFrame(df_moped_filter, geometry="geometry")

# %%
gdf_moped.head()
# Out:
#     project_id  project_component_id  \
# 10          12                 181.0
# 11          12                 183.0
# 12          12                 469.0
# 13          12                 182.0
# 14          12                  16.0
#
#                                              geometry  \
# 10                    MULTIPOINT (-97.73351 30.26751)
# 11                    MULTIPOINT (-97.73430 30.26772)
# 12  MULTIPOINT (-97.73467 30.26683, -97.73431 30.2...
# 13                    MULTIPOINT (-97.73386 30.26657)
# 14                    MULTIPOINT (-97.73467 30.26682)
#
#                                         line_geometry  \
# 10  {'type': 'LineString', 'coordinates': [[-97.73...
# 11  {'type': 'LineString', 'coordinates': [[-97.73...
# 12  {'type': 'MultiLineString', 'coordinates': [[[...
# 13  {'type': 'LineString', 'coordinates': [[-97.73...
# 14  {'type': 'LineString', 'coordinates': [[-97.73...
#
#    substantial_completion_date substantial_completion_date_estimated  \
# 10   2022-10-10 05:00:00+00:00                                   NaT
# 11   2022-10-10 05:00:00+00:00                                   NaT
# 12   2022-10-10 05:00:00+00:00                                   NaT
# 13   2022-10-10 05:00:00+00:00                                   NaT
# 14   2022-10-10 05:00:00+00:00                                   NaT
#
#    completion_date       completion_end_date
# 10             NaT 2022-12-30 06:00:00+00:00
# 11             NaT 2022-12-30 06:00:00+00:00
# 12             NaT 2022-12-30 06:00:00+00:00
# 13             NaT 2022-12-30 06:00:00+00:00
# 14             NaT 2022-12-30 06:00:00+00:00

# %%
df_moped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12080 entries, 0 to 12079
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   project_id                             12080 non-null  int64
#  1   project_component_id                   11632 non-null  float64
#  2   geometry                               11632 non-null  object
#  3   line_geometry                          11632 non-null  object
#  4   substantial_completion_date            2851 non-null   datetime64[ns, UTC]
#  5   substantial_completion_date_estimated  348 non-null    datetime64[ns, UTC]
#  6   completion_date                        349 non-null    datetime64[ns, UTC]
#  7   completion_end_date                    213 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](4), float64(1), int64(1), object(2)
# memory usage: 755.1+ KB

# %%
df_moped_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2851 entries, 10 to 12074
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   project_id                             2851 non-null   int64
#  1   project_component_id                   2668 non-null   float64
#  2   geometry                               2668 non-null   object
#  3   line_geometry                          2668 non-null   object
#  4   substantial_completion_date            2851 non-null   datetime64[ns, UTC]
#  5   substantial_completion_date_estimated  25 non-null     datetime64[ns, UTC]
#  6   completion_date                        349 non-null    datetime64[ns, UTC]
#  7   completion_end_date                    181 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](4), float64(1), int64(1), object(2)
# memory usage: 200.5+ KB

# %% [markdown]
# # VisionZero processing

# %%
# Creaing vision zero dataframe
QUERY_CRASH_DATA = """SELECT crash_id, crash_fatal_fl, crash_date, rpt_latitude,
rpt_longitude, road_constr_zone_fl, latitude, longitude, tot_injry_cnt, death_cnt 
FROM atd_txdot_crashes"""

df_vz = get_data(QUERY_CRASH_DATA, cursor_vz)
df_vz.to_csv('df_vz.csv')

# %%
df_vz.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 417945 entries, 0 to 417944
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   crash_id             417945 non-null  int64
#  1   crash_fatal_fl       417945 non-null  object
#  2   crash_date           417945 non-null  object
#  3   rpt_latitude         62487 non-null   float64
#  4   rpt_longitude        62487 non-null   float64
#  5   road_constr_zone_fl  417943 non-null  object
#  6   latitude             386519 non-null  float64
#  7   longitude            386519 non-null  float64
#  8   tot_injry_cnt        417943 non-null  float64
#  9   death_cnt            417944 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 31.9+ MB

# %%
# Filtering

# Keepiing only those observations where x-y coordinates are present
df_vz_filter = df_vz[df_vz['latitude'].notnull() & df_vz['longitude'].notnull()]

# %%
df_vz_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 386519 entries, 0 to 417944
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   crash_id             386519 non-null  int64
#  1   crash_fatal_fl       386519 non-null  object
#  2   crash_date           386519 non-null  object
#  3   rpt_latitude         60310 non-null   float64
#  4   rpt_longitude        60310 non-null   float64
#  5   road_constr_zone_fl  386519 non-null  object
#  6   latitude             386519 non-null  float64
#  7   longitude            386519 non-null  float64
#  8   tot_injry_cnt        386519 non-null  float64
#  9   death_cnt            386519 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 32.4+ MB

# %%
# Convert timestamp columns to string using .loc
timestamp_columns = ["crash_date"]

for col in timestamp_columns:
    df_vz_filter.loc[:, col] = df_vz_filter[col].astype(str)

# %%
# Creating geodataframe
gdf_vz = gpd.GeoDataFrame(df_vz_filter,
                          geometry=gpd.points_from_xy(df_vz_filter.longitude,
                                                      df_vz_filter.latitude),
                                                      crs='EPSG:4326')

gdf_vz.head()
# Out:
#    crash_id crash_fatal_fl  crash_date  rpt_latitude  rpt_longitude  \
# 0  13118092              N  2013-01-25           NaN            NaN
# 1  13118095              N  2013-01-25           NaN            NaN
# 2  13110170              N  2013-01-24           NaN            NaN
# 3  15735606              N  2017-04-26           NaN            NaN
# 4  15536425              N  2015-11-25           NaN            NaN
#
#   road_constr_zone_fl   latitude  longitude  tot_injry_cnt  death_cnt  \
# 0                   N  30.430933 -97.700708            1.0        0.0
# 1                   N  30.241433 -97.728098            0.0        0.0
# 2                   N  30.377071 -97.739046            0.0        0.0
# 3                   N  29.884583 -97.924178            0.0        0.0
# 4                   N  30.413076 -97.690751            2.0        0.0
#
#                      geometry
# 0  POINT (-97.70071 30.43093)
# 1  POINT (-97.72810 30.24143)
# 2  POINT (-97.73905 30.37707)
# 3  POINT (-97.92418 29.88458)
# 4  POINT (-97.69075 30.41308)

# %%
# Plotting
fig, ax = plt.subplots(figsize=(20, 13.33))
gdf_vz.plot(ax=ax, markersize=0.5)  
plt.title('Austin crash incidents (VisionZero)')
plt.show()

# %% [markdown]
# # Spatial join

# %%
gdf_vz.head()
# Out:
#    crash_id crash_fatal_fl  crash_date  rpt_latitude  rpt_longitude  \
# 0  13118092              N  2013-01-25           NaN            NaN
# 1  13118095              N  2013-01-25           NaN            NaN
# 2  13110170              N  2013-01-24           NaN            NaN
# 3  15735606              N  2017-04-26           NaN            NaN
# 4  15536425              N  2015-11-25           NaN            NaN
#
#   road_constr_zone_fl   latitude  longitude  tot_injry_cnt  death_cnt  \
# 0                   N  30.430933 -97.700708            1.0        0.0
# 1                   N  30.241433 -97.728098            0.0        0.0
# 2                   N  30.377071 -97.739046            0.0        0.0
# 3                   N  29.884583 -97.924178            0.0        0.0
# 4                   N  30.413076 -97.690751            2.0        0.0
#
#                      geometry
# 0  POINT (-97.70071 30.43093)
# 1  POINT (-97.72810 30.24143)
# 2  POINT (-97.73905 30.37707)
# 3  POINT (-97.92418 29.88458)
# 4  POINT (-97.69075 30.41308)

# %%
gdf_moped.head()
# Out:
#     project_id  project_component_id  \
# 10          12                 181.0
# 11          12                 183.0
# 12          12                 469.0
# 13          12                 182.0
# 14          12                  16.0
#
#                                              geometry  \
# 10                    MULTIPOINT (-97.73351 30.26751)
# 11                    MULTIPOINT (-97.73430 30.26772)
# 12  MULTIPOINT (-97.73467 30.26683, -97.73431 30.2...
# 13                    MULTIPOINT (-97.73386 30.26657)
# 14                    MULTIPOINT (-97.73467 30.26682)
#
#                                         line_geometry  \
# 10  {'type': 'LineString', 'coordinates': [[-97.73...
# 11  {'type': 'LineString', 'coordinates': [[-97.73...
# 12  {'type': 'MultiLineString', 'coordinates': [[[...
# 13  {'type': 'LineString', 'coordinates': [[-97.73...
# 14  {'type': 'LineString', 'coordinates': [[-97.73...
#
#    substantial_completion_date substantial_completion_date_estimated  \
# 10   2022-10-10 05:00:00+00:00                                   NaT
# 11   2022-10-10 05:00:00+00:00                                   NaT
# 12   2022-10-10 05:00:00+00:00                                   NaT
# 13   2022-10-10 05:00:00+00:00                                   NaT
# 14   2022-10-10 05:00:00+00:00                                   NaT
#
#    completion_date       completion_end_date
# 10             NaT 2022-12-30 06:00:00+00:00
# 11             NaT 2022-12-30 06:00:00+00:00
# 12             NaT 2022-12-30 06:00:00+00:00
# 13             NaT 2022-12-30 06:00:00+00:00
# 14             NaT 2022-12-30 06:00:00+00:00

# %%
gdf_moped.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 2851 entries, 10 to 12074
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   project_id                             2851 non-null   int64
#  1   project_component_id                   2668 non-null   float64
#  2   geometry                               2668 non-null   geometry
#  3   line_geometry                          2668 non-null   object
#  4   substantial_completion_date            2851 non-null   datetime64[ns, UTC]
#  5   substantial_completion_date_estimated  25 non-null     datetime64[ns, UTC]
#  6   completion_date                        349 non-null    datetime64[ns, UTC]
#  7   completion_end_date                    181 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](4), float64(1), geometry(1), int64(1), object(1)
# memory usage: 200.5+ KB

# %%
# Keeping only those observations where line_geometry is available
gdf_moped = gdf_moped.dropna(subset=['line_geometry'])

# %%
# Function to parase line_geometry column in the moped data frame
def parse_linestring(line_geom):

    if line_geom['type'] == 'LineString':
        coordinates = [tuple(coord) for coord in line_geom['coordinates']]
        return LineString(coordinates)
    elif line_geom['type'] == 'MultiLineString':
        lines = [LineString([tuple(coord) for coord in line]) for line in line_geom['coordinates']]
        return MultiLineString(lines)
    else:
        raise ValueError(f"Unexpected geometry type: {line_geom['type']}")

gdf_moped['line_geometry'] = gdf_moped['line_geometry'].apply(parse_linestring)

# %%
gdf_moped.head()
# Out:
#     project_id  project_component_id  \
# 10          12                 181.0
# 11          12                 183.0
# 12          12                 469.0
# 13          12                 182.0
# 14          12                  16.0
#
#                                              geometry  \
# 10                    MULTIPOINT (-97.73351 30.26751)
# 11                    MULTIPOINT (-97.73430 30.26772)
# 12  MULTIPOINT (-97.73467 30.26683, -97.73431 30.2...
# 13                    MULTIPOINT (-97.73386 30.26657)
# 14                    MULTIPOINT (-97.73467 30.26682)
#
#                                         line_geometry  \
# 10  LINESTRING (-97.733436244 30.267508296, -97.73...
# 11  LINESTRING (-97.73422624299999 30.267724297, -...
# 12  MULTILINESTRING ((-97.734601244 30.266825297, ...
# 13  LINESTRING (-97.73378324399999 30.266570296, -...
# 14  LINESTRING (-97.734592244 30.266820297, -97.73...
#
#    substantial_completion_date substantial_completion_date_estimated  \
# 10   2022-10-10 05:00:00+00:00                                   NaT
# 11   2022-10-10 05:00:00+00:00                                   NaT
# 12   2022-10-10 05:00:00+00:00                                   NaT
# 13   2022-10-10 05:00:00+00:00                                   NaT
# 14   2022-10-10 05:00:00+00:00                                   NaT
#
#    completion_date       completion_end_date
# 10             NaT 2022-12-30 06:00:00+00:00
# 11             NaT 2022-12-30 06:00:00+00:00
# 12             NaT 2022-12-30 06:00:00+00:00
# 13             NaT 2022-12-30 06:00:00+00:00
# 14             NaT 2022-12-30 06:00:00+00:00

# %%
# Adding a unique ID column to the moped data frame
gdf_moped.insert(0, 'moped_component_id', range(1, 1 + len(gdf_moped)))

# %%
# Creating buffer for joining
gdf_moped = gdf_moped.set_geometry('line_geometry')
gdf_moped.set_crs(epsg=4326, inplace=True)
gdf_moped_proj = gdf_moped.to_crs(epsg=32614)
buffer_distance = 100

gdf_moped_proj = gdf_moped.to_crs(epsg=32614)

# %%
gdf_moped_proj['buffered_geometry'] = gdf_moped_proj.geometry.buffer(buffer_distance)
buffered_moped_gdf = gdf_moped_proj.set_geometry('buffered_geometry').to_crs('EPSG:4326')

# %%
buffered_moped_gdf.head()
# Out:
#     moped_component_id  project_id  project_component_id  \
# 10                   1          12                 181.0
# 11                   2          12                 183.0
# 12                   3          12                 469.0
# 13                   4          12                 182.0
# 14                   5          12                  16.0
#
#                                              geometry  \
# 10                    MULTIPOINT (-97.73351 30.26751)
# 11                    MULTIPOINT (-97.73430 30.26772)
# 12  MULTIPOINT (-97.73467 30.26683, -97.73431 30.2...
# 13                    MULTIPOINT (-97.73386 30.26657)
# 14                    MULTIPOINT (-97.73467 30.26682)
#
#                                         line_geometry  \
# 10  LINESTRING (621833.101 3349106.852, 621832.966...
# 11  LINESTRING (621756.837 3349129.944, 621756.702...
# 12  MULTILINESTRING ((621721.871 3349029.909, 6217...
# 13  LINESTRING (621800.878 3349002.525, 621800.743...
# 14  LINESTRING (621722.743 3349029.365, 621722.609...
#
#    substantial_completion_date substantial_completion_date_estimated  \
# 10   2022-10-10 05:00:00+00:00                                   NaT
# 11   2022-10-10 05:00:00+00:00                                   NaT
# 12   2022-10-10 05:00:00+00:00                                   NaT
# 13   2022-10-10 05:00:00+00:00                                   NaT
# 14   2022-10-10 05:00:00+00:00                                   NaT
#
#    completion_date       completion_end_date  \
# 10             NaT 2022-12-30 06:00:00+00:00
# 11             NaT 2022-12-30 06:00:00+00:00
# 12             NaT 2022-12-30 06:00:00+00:00
# 13             NaT 2022-12-30 06:00:00+00:00
# 14             NaT 2022-12-30 06:00:00+00:00
#
#                                     buffered_geometry
# 10  POLYGON ((-97.73240 30.26759, -97.73240 30.267...
# 11  POLYGON ((-97.73319 30.26780, -97.73319 30.267...
# 12  POLYGON ((-97.73461 30.26586, -97.73469 30.265...
# 13  POLYGON ((-97.73275 30.26665, -97.73274 30.266...
# 14  POLYGON ((-97.73356 30.26690, -97.73355 30.266...

# %%
buffered_moped_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 2668 entries, 10 to 12074
# Data columns (total 10 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   moped_component_id                     2668 non-null   int64
#  1   project_id                             2668 non-null   int64
#  2   project_component_id                   2668 non-null   float64
#  3   geometry                               2668 non-null   geometry
#  4   line_geometry                          2668 non-null   geometry
#  5   substantial_completion_date            2668 non-null   datetime64[ns, UTC]
#  6   substantial_completion_date_estimated  25 non-null     datetime64[ns, UTC]
#  7   completion_date                        338 non-null    datetime64[ns, UTC]
#  8   completion_end_date                    181 non-null    datetime64[ns, UTC]
#  9   buffered_geometry                      2668 non-null   geometry
# dtypes: datetime64[ns, UTC](4), float64(1), geometry(3), int64(2)
# memory usage: 229.3 KB

# %%
# Perform the spatial join
crashes_near_projects = gpd.sjoin(gdf_vz, buffered_moped_gdf, how='inner')

# Creating a unique ID column
crashes_near_projects['crash_project_component_id'] = crashes_near_projects['crash_id'].astype(str) + "-" + crashes_near_projects['project_id'].astype(str) + "-" + crashes_near_projects['project_component_id'].astype(str)

# %%
print(crashes_near_projects['crash_project_component_id'].nunique())
print(gdf_vz['crash_id'].nunique())
print(gdf_moped['moped_component_id'].nunique())
# Out:
# 338234
# 386519
# 2668

# %%
print('Number of unique crashes in merged dataset:', crashes_near_projects['crash_id'].nunique())
print('Number of unique moped component IDs in merged dataset:', crashes_near_projects['moped_component_id'].nunique())
# Out:
# Number of unique crashes in merged dataset: 135444
# Number of unique moped component IDs in merged dataset: 2182

# %%
# Plot the mobility projects and crashes on a static map
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the buffered geometries (mobility projects)
buffered_moped_gdf.plot(ax=ax, facecolor='none', edgecolor='blue', linewidth=1, alpha=0.15, label='Mobility Project Buffers')

# Plot the original line geometries (mobility projects)
gdf_moped.plot(ax=ax, color='black', label='Mobility Project')

# Plot the crash data points
# crashes_near_projects.plot(ax=ax, color='red', markersize=5, label='Crashes within Buffer')

# Enhance the plot with titles and legend
ax.set_title('Crashes Near Mobility Projects')
plt.legend()
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)

plt.show()
# Out:
# /var/folders/x5/pthbxv090m7gl62qzh4g2lzm0000gn/T/ipykernel_74177/1616841083.py:15: UserWarning: Legend does not support handles for PatchCollection instances.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#implementing-a-custom-legend-handler
#   plt.legend()

# %%
crashes_near_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338234 entries, 0 to 415149
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   crash_id                               338234 non-null  int64
#  1   crash_fatal_fl                         338234 non-null  object
#  2   crash_date                             338234 non-null  object
#  3   rpt_latitude                           24914 non-null   float64
#  4   rpt_longitude                          24914 non-null   float64
#  5   road_constr_zone_fl                    338234 non-null  object
#  6   latitude                               338234 non-null  float64
#  7   longitude                              338234 non-null  float64
#  8   tot_injry_cnt                          338234 non-null  float64
#  9   death_cnt                              338234 non-null  float64
#  10  geometry_left                          338234 non-null  geometry
#  11  index_right                            338234 non-null  int64
#  12  moped_component_id                     338234 non-null  int64
#  13  project_id                             338234 non-null  int64
#  14  project_component_id                   338234 non-null  float64
#  15  geometry_right                         338234 non-null  geometry
#  16  line_geometry                          338234 non-null  geometry
#  17  substantial_completion_date            338234 non-null  datetime64[ns, UTC]
#  18  substantial_completion_date_estimated  5054 non-null    datetime64[ns, UTC]
#  19  completion_date                        32614 non-null   datetime64[ns, UTC]
#  20  completion_end_date                    8966 non-null    datetime64[ns, UTC]
#  21  crash_project_component_id             338234 non-null  object
# dtypes: datetime64[ns, UTC](4), float64(7), geometry(3), int64(4), object(4)
# memory usage: 59.4+ MB

# %%
crashes_near_projects.head()
# Out:
#       crash_id crash_fatal_fl  crash_date  rpt_latitude  rpt_longitude  \
# 0     13118092              N  2013-01-25           NaN            NaN
# 725   18407113              N  2021-08-08           NaN            NaN
# 1497  13306837              N  2012-12-31      30.43244      -97.70052
# 3258  13018929              N  2012-12-01           NaN            NaN
# 5490  18797163              N  2022-03-14           NaN            NaN
#
#      road_constr_zone_fl   latitude  longitude  tot_injry_cnt  death_cnt  ...  \
# 0                      N  30.430933 -97.700708            1.0        0.0  ...
# 725                    N  30.430795 -97.700740            0.0        0.0  ...
# 1497                   N  30.430783 -97.700758            0.0        0.0  ...
# 3258                   N  30.430618 -97.700812            0.0        0.0  ...
# 5490                   N  30.429470 -97.695959            1.0        0.0  ...
#
#      moped_component_id  project_id  project_component_id  \
# 0                   200         652                 859.0
# 725                 200         652                 859.0
# 1497                200         652                 859.0
# 3258                200         652                 859.0
# 5490                200         652                 859.0
#
#                                          geometry_right  \
# 0     MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 725   MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 1497  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 3258  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 5490  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
#
#                                           line_geometry  \
# 0     MULTILINESTRING ((626647.799 3366991.674, 6265...
# 725   MULTILINESTRING ((626647.799 3366991.674, 6265...
# 1497  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 3258  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 5490  MULTILINESTRING ((626647.799 3366991.674, 6265...
#
#      substantial_completion_date substantial_completion_date_estimated  \
# 0      2008-01-01 06:00:00+00:00                                   NaT
# 725    2008-01-01 06:00:00+00:00                                   NaT
# 1497   2008-01-01 06:00:00+00:00                                   NaT
# 3258   2008-01-01 06:00:00+00:00                                   NaT
# 5490   2008-01-01 06:00:00+00:00                                   NaT
#
#      completion_date completion_end_date crash_project_component_id
# 0                NaT                 NaT         13118092-652-859.0
# 725              NaT                 NaT         18407113-652-859.0
# 1497             NaT                 NaT         13306837-652-859.0
# 3258             NaT                 NaT         13018929-652-859.0
# 5490             NaT                 NaT         18797163-652-859.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Analysis

# %%
# Converting crash date to datetime format
crashes_near_projects['crash_date'] = pd.to_datetime(crashes_near_projects['crash_date']).dt.tz_localize('UTC', nonexistent='NaT', ambiguous='NaT')

# %%
# Converting crash date to datetime format
crashes_near_projects['crash_date'] = pd.to_datetime(crashes_near_projects['crash_date']).dt.tz_convert('UTC')

# %%
crashes_near_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338234 entries, 0 to 415149
# Data columns (total 22 columns):
#  #   Column                                 Non-Null Count   Dtype
# ---  ------                                 --------------   -----
#  0   crash_id                               338234 non-null  int64
#  1   crash_fatal_fl                         338234 non-null  object
#  2   crash_date                             338234 non-null  datetime64[ns, UTC]
#  3   rpt_latitude                           24914 non-null   float64
#  4   rpt_longitude                          24914 non-null   float64
#  5   road_constr_zone_fl                    338234 non-null  object
#  6   latitude                               338234 non-null  float64
#  7   longitude                              338234 non-null  float64
#  8   tot_injry_cnt                          338234 non-null  float64
#  9   death_cnt                              338234 non-null  float64
#  10  geometry_left                          338234 non-null  geometry
#  11  index_right                            338234 non-null  int64
#  12  moped_component_id                     338234 non-null  int64
#  13  project_id                             338234 non-null  int64
#  14  project_component_id                   338234 non-null  float64
#  15  geometry_right                         338234 non-null  geometry
#  16  line_geometry                          338234 non-null  geometry
#  17  substantial_completion_date            338234 non-null  datetime64[ns, UTC]
#  18  substantial_completion_date_estimated  5054 non-null    datetime64[ns, UTC]
#  19  completion_date                        32614 non-null   datetime64[ns, UTC]
#  20  completion_end_date                    8966 non-null    datetime64[ns, UTC]
#  21  crash_project_component_id             338234 non-null  object
# dtypes: datetime64[ns, UTC](5), float64(7), geometry(3), int64(4), object(3)
# memory usage: 59.4+ MB

# %%
# Dropping columns
crashes_near_projects.drop(columns=['rpt_latitude', 
                                    'rpt_longitude', 
                                    'substantial_completion_date_estimated', 
                                    'completion_date', 
                                    'completion_end_date'], inplace=True)

# %%
# Re-arranging columns
# First column is the unique identifier for each observation
crashes_near_projects.insert(0, 'crash_project_component_id', crashes_near_projects.pop('crash_project_component_id'))

# moped_component_id
crashes_near_projects.insert(2, 'moped_component_id', crashes_near_projects.pop('moped_component_id'))

# crash_date
crashes_near_projects.insert(4, 'crash_date', crashes_near_projects.pop('crash_date'))

# project compoenent ID
crashes_near_projects.insert(3, 'project_component_id', crashes_near_projects.pop('project_component_id'))

# Substantial completion date
crashes_near_projects.insert(5, 'substantial_completion_date', crashes_near_projects.pop('substantial_completion_date'))

# %%
crashes_near_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338234 entries, 0 to 415149
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   crash_project_component_id   338234 non-null  object
#  1   crash_id                     338234 non-null  int64
#  2   moped_component_id           338234 non-null  int64
#  3   project_component_id         338234 non-null  float64
#  4   crash_fatal_fl               338234 non-null  object
#  5   substantial_completion_date  338234 non-null  datetime64[ns, UTC]
#  6   crash_date                   338234 non-null  datetime64[ns, UTC]
#  7   road_constr_zone_fl          338234 non-null  object
#  8   latitude                     338234 non-null  float64
#  9   longitude                    338234 non-null  float64
#  10  tot_injry_cnt                338234 non-null  float64
#  11  death_cnt                    338234 non-null  float64
#  12  geometry_left                338234 non-null  geometry
#  13  index_right                  338234 non-null  int64
#  14  project_id                   338234 non-null  int64
#  15  geometry_right               338234 non-null  geometry
#  16  line_geometry                338234 non-null  geometry
# dtypes: datetime64[ns, UTC](2), float64(5), geometry(3), int64(4), object(3)
# memory usage: 46.4+ MB

# %%
# Creating indicator variables for crash occuring pre and post completion of mobility project
crashes_near_projects.insert(7, 'crash_pre_completion', crashes_near_projects['crash_date'] < crashes_near_projects['substantial_completion_date'])
crashes_near_projects.insert(8, 'crash_post_completion', crashes_near_projects['crash_date'] > crashes_near_projects['substantial_completion_date'])

# %%
# Creating time difference variables
crashes_near_projects.insert(9, 'crash_project_date_diff', crashes_near_projects['substantial_completion_date'] - crashes_near_projects['crash_date'])

# %%
crashes_near_projects.head()
# Out:
#      crash_project_component_id  crash_id  moped_component_id  \
# 0            13118092-652-859.0  13118092                 200
# 725          18407113-652-859.0  18407113                 200
# 1497         13306837-652-859.0  13306837                 200
# 3258         13018929-652-859.0  13018929                 200
# 5490         18797163-652-859.0  18797163                 200
#
#       project_component_id crash_fatal_fl substantial_completion_date  \
# 0                    859.0              N   2008-01-01 06:00:00+00:00
# 725                  859.0              N   2008-01-01 06:00:00+00:00
# 1497                 859.0              N   2008-01-01 06:00:00+00:00
# 3258                 859.0              N   2008-01-01 06:00:00+00:00
# 5490                 859.0              N   2008-01-01 06:00:00+00:00
#
#                     crash_date  crash_pre_completion  crash_post_completion  \
# 0    2013-01-25 00:00:00+00:00                 False                   True
# 725  2021-08-08 00:00:00+00:00                 False                   True
# 1497 2012-12-31 00:00:00+00:00                 False                   True
# 3258 2012-12-01 00:00:00+00:00                 False                   True
# 5490 2022-03-14 00:00:00+00:00                 False                   True
#
#      crash_project_date_diff road_constr_zone_fl   latitude  longitude  \
# 0       -1851 days +06:00:00                   N  30.430933 -97.700708
# 725     -4968 days +06:00:00                   N  30.430795 -97.700740
# 1497    -1826 days +06:00:00                   N  30.430783 -97.700758
# 3258    -1796 days +06:00:00                   N  30.430618 -97.700812
# 5490    -5186 days +06:00:00                   N  30.429470 -97.695959
#
#       tot_injry_cnt  death_cnt               geometry_left  index_right  \
# 0               1.0        0.0  POINT (-97.70071 30.43093)          891
# 725             0.0        0.0  POINT (-97.70074 30.43080)          891
# 1497            0.0        0.0  POINT (-97.70076 30.43078)          891
# 3258            0.0        0.0  POINT (-97.70081 30.43062)          891
# 5490            1.0        0.0  POINT (-97.69596 30.42947)          891
#
#       project_id                                     geometry_right  \
# 0            652  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 725          652  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 1497         652  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 3258         652  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 5490         652  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
#
#                                           line_geometry
# 0     MULTILINESTRING ((626647.799 3366991.674, 6265...
# 725   MULTILINESTRING ((626647.799 3366991.674, 6265...
# 1497  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 3258  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 5490  MULTILINESTRING ((626647.799 3366991.674, 6265...

# %%
crashes_near_projects.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 338234 entries, 0 to 415149
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   crash_project_component_id   338234 non-null  object
#  1   crash_id                     338234 non-null  int64
#  2   moped_component_id           338234 non-null  int64
#  3   project_component_id         338234 non-null  float64
#  4   crash_fatal_fl               338234 non-null  object
#  5   substantial_completion_date  338234 non-null  datetime64[ns, UTC]
#  6   crash_date                   338234 non-null  datetime64[ns, UTC]
#  7   crash_pre_completion         338234 non-null  bool
#  8   crash_post_completion        338234 non-null  bool
#  9   crash_project_date_diff      338234 non-null  timedelta64[ns]
#  10  road_constr_zone_fl          338234 non-null  object
#  11  latitude                     338234 non-null  float64
#  12  longitude                    338234 non-null  float64
#  13  tot_injry_cnt                338234 non-null  float64
#  14  death_cnt                    338234 non-null  float64
#  15  geometry_left                338234 non-null  geometry
#  16  index_right                  338234 non-null  int64
#  17  project_id                   338234 non-null  int64
#  18  geometry_right               338234 non-null  geometry
#  19  line_geometry                338234 non-null  geometry
# dtypes: bool(2), datetime64[ns, UTC](2), float64(5), geometry(3), int64(4), object(3), timedelta64[ns](1)
# memory usage: 49.7+ MB

# %%
# Function to calculate duration in years
def calculate_duration(df, date_col1, date_col2):
    duration = (df[date_col2] - df[date_col1]).dt.total_seconds() / (365.25 * 24 * 3600)
    return duration

# %%
crashes_near_projects['pre_completion_duration'] = crashes_near_projects['crash_pre_completion'] * calculate_duration(crashes_near_projects, 'crash_date', 'substantial_completion_date')
crashes_near_projects['post_completion_duration'] = crashes_near_projects['crash_post_completion'] * calculate_duration(crashes_near_projects, 'substantial_completion_date', 'crash_date')

# %%
pre_completion_stats = crashes_near_projects[crashes_near_projects['crash_pre_completion']].groupby('moped_component_id').agg({
    'crash_id': 'count',
    'pre_completion_duration': 'sum'
}).rename(columns={'crash_id': 'pre_crash_count'})

post_completion_stats = crashes_near_projects[crashes_near_projects['crash_post_completion']].groupby('moped_component_id').agg({
    'crash_id': 'count',
    'post_completion_duration': 'sum'
}).rename(columns={'crash_id': 'post_crash_count'})

# %%
annualized_crash_rate = pre_completion_stats.merge(post_completion_stats, on='moped_component_id', how='outer').fillna(0)

# %%
annualized_crash_rate['pre_annualized_crash_rate'] = annualized_crash_rate['pre_crash_count'] / annualized_crash_rate['pre_completion_duration']
annualized_crash_rate['post_annualized_crash_rate'] = annualized_crash_rate['post_crash_count'] / annualized_crash_rate['post_completion_duration']

# %%
# Getting completion date for each moped component id
completion_dates = crashes_near_projects.groupby('moped_component_id')['substantial_completion_date'].first().reset_index()

# Merging into the annualized crash rate DataFrame
annualized_crash_rate = annualized_crash_rate.merge(completion_dates, on='moped_component_id', how='left')

# %%
annualized_crash_rate = annualized_crash_rate[['pre_annualized_crash_rate', 'post_annualized_crash_rate']]
print(annualized_crash_rate)
# Out:
#                     pre_annualized_crash_rate  post_annualized_crash_rate
# moped_component_id
# 1                                    0.140613                    0.951688
# 2                                    0.181301                    1.179018
# 3                                    0.170834                    1.117001
# 4                                    0.159645                    1.058951
# 5                                    0.183909                    1.282516
# ...                                       ...                         ...
# 2446                                      NaN                    0.052436
# 2527                                      NaN                    4.259475
# 2539                                      NaN                    0.513142
# 2604                                      NaN                    0.670440
# 2616                                      NaN                    0.213373
#
# [2182 rows x 2 columns]

# %%
crashes_near_projects.loc[crashes_near_projects['moped_component_id'] == 2446]
# Out:
#        crash_project_component_id  crash_id  moped_component_id  \
# 15202       20210293-3122-10867.0  20210293                2446
# 43097       15551369-3122-10867.0  15551369                2446
# 170073      16513861-3122-10867.0  16513861                2446
# 175065      17083234-3122-10867.0  17083234                2446
# 178086      17125980-3122-10867.0  17125980                2446
# 178934      16703734-3122-10867.0  16703734                2446
# 243584      14608565-3122-10867.0  14608565                2446
# 307457      13268084-3122-10867.0  13268084                2446
# 327300      12901725-3122-10867.0  12901725                2446
# 377308      16932825-3122-10867.0  16932825                2446
# 402642      18054644-3122-10867.0  18054644                2446
#
#         project_component_id crash_fatal_fl substantial_completion_date  \
# 15202                10867.0              N   1999-01-01 06:00:00+00:00
# 43097                10867.0              N   1999-01-01 06:00:00+00:00
# 170073               10867.0              N   1999-01-01 06:00:00+00:00
# 175065               10867.0              N   1999-01-01 06:00:00+00:00
# 178086               10867.0              N   1999-01-01 06:00:00+00:00
# 178934               10867.0              N   1999-01-01 06:00:00+00:00
# 243584               10867.0              N   1999-01-01 06:00:00+00:00
# 307457               10867.0              N   1999-01-01 06:00:00+00:00
# 327300               10867.0              N   1999-01-01 06:00:00+00:00
# 377308               10867.0              N   1999-01-01 06:00:00+00:00
# 402642               10867.0              N   1999-01-01 06:00:00+00:00
#
#                       crash_date  crash_pre_completion  crash_post_completion  \
# 15202  2024-05-29 00:00:00+00:00                 False                   True
# 43097  2017-01-22 00:00:00+00:00                 False                   True
# 170073 2018-07-03 00:00:00+00:00                 False                   True
# 175065 2019-05-17 00:00:00+00:00                 False                   True
# 178086 2018-10-26 00:00:00+00:00                 False                   True
# 178934 2018-10-25 00:00:00+00:00                 False                   True
# 243584 2015-08-22 00:00:00+00:00                 False                   True
# 307457 2013-05-07 00:00:00+00:00                 False                   True
# 327300 2012-09-13 00:00:00+00:00                 False                   True
# 377308 2019-03-05 00:00:00+00:00                 False                   True
# 402642 2020-12-17 00:00:00+00:00                 False                   True
#
#        crash_project_date_diff  ...  longitude  tot_injry_cnt  death_cnt  \
# 15202     -9280 days +06:00:00  ... -97.733907            0.0        0.0
# 43097     -6596 days +06:00:00  ... -97.734426            0.0        0.0
# 170073    -7123 days +06:00:00  ... -97.733769            2.0        0.0
# 175065    -7441 days +06:00:00  ... -97.734508            0.0        0.0
# 178086    -7238 days +06:00:00  ... -97.734508            0.0        0.0
# 178934    -7237 days +06:00:00  ... -97.733957            0.0        0.0
# 243584    -6077 days +06:00:00  ... -97.734512            1.0        0.0
# 307457    -5240 days +06:00:00  ... -97.734543            1.0        0.0
# 327300    -5004 days +06:00:00  ... -97.734528            1.0        0.0
# 377308    -7368 days +06:00:00  ... -97.734494            0.0        0.0
# 402642    -8021 days +06:00:00  ... -97.734027            0.0        0.0
#
#                      geometry_left  index_right project_id  \
# 15202   POINT (-97.73391 30.33201)        10934       3122
# 43097   POINT (-97.73443 30.33226)        10934       3122
# 170073  POINT (-97.73377 30.33195)        10934       3122
# 175065  POINT (-97.73451 30.33230)        10934       3122
# 178086  POINT (-97.73451 30.33230)        10934       3122
# 178934  POINT (-97.73396 30.33204)        10934       3122
# 243584  POINT (-97.73451 30.33114)        10934       3122
# 307457  POINT (-97.73454 30.33232)        10934       3122
# 327300  POINT (-97.73453 30.33231)        10934       3122
# 377308  POINT (-97.73449 30.33229)        10934       3122
# 402642  POINT (-97.73403 30.33207)        10934       3122
#
#                                            geometry_right  \
# 15202   MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 43097   MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 170073  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 175065  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 178086  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 178934  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 243584  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 307457  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 327300  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 377308  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
# 402642  MULTILINESTRING ((-97.73461 30.33139, -97.7344...
#
#                                             line_geometry  \
# 15202   MULTILINESTRING ((621641.178 3356185.624, 6216...
# 43097   MULTILINESTRING ((621641.178 3356185.624, 6216...
# 170073  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 175065  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 178086  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 178934  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 243584  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 307457  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 327300  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 377308  MULTILINESTRING ((621641.178 3356185.624, 6216...
# 402642  MULTILINESTRING ((621641.178 3356185.624, 6216...
#
#        pre_completion_duration post_completion_duration
# 15202                     -0.0                25.406571
# 43097                     -0.0                18.058179
# 170073                    -0.0                19.501027
# 175065                    -0.0                20.371663
# 178086                    -0.0                19.815880
# 178934                    -0.0                19.813142
# 243584                    -0.0                16.637235
# 307457                    -0.0                14.345654
# 327300                    -0.0                13.699521
# 377308                    -0.0                20.171800
# 402642                    -0.0                21.959617
#
# [11 rows x 22 columns]

# %%
min_crash_date = crashes_near_projects['crash_date'].min()
min_crash_date
# Out:
# Timestamp('2010-01-01 00:00:00+0000', tz='UTC')

# %%
crashes_near_projects.head()
# Out:
#       crash_id crash_fatal_fl                crash_date  rpt_latitude  \
# 0     13118092              N 2013-01-25 00:00:00+00:00           NaN
# 725   18407113              N 2021-08-08 00:00:00+00:00           NaN
# 1497  13306837              N 2012-12-31 00:00:00+00:00      30.43244
# 3258  13018929              N 2012-12-01 00:00:00+00:00           NaN
# 5490  18797163              N 2022-03-14 00:00:00+00:00           NaN
#
#       rpt_longitude road_constr_zone_fl   latitude  longitude  tot_injry_cnt  \
# 0               NaN                   N  30.430933 -97.700708            1.0
# 725             NaN                   N  30.430795 -97.700740            0.0
# 1497      -97.70052                   N  30.430783 -97.700758            0.0
# 3258            NaN                   N  30.430618 -97.700812            0.0
# 5490            NaN                   N  30.429470 -97.695959            1.0
#
#       death_cnt  ... project_component_id  \
# 0           0.0  ...                859.0
# 725         0.0  ...                859.0
# 1497        0.0  ...                859.0
# 3258        0.0  ...                859.0
# 5490        0.0  ...                859.0
#
#                                          geometry_right  \
# 0     MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 725   MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 1497  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 3258  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
# 5490  MULTILINESTRING ((-97.68123 30.42837, -97.6824...
#
#                                           line_geometry  \
# 0     MULTILINESTRING ((626647.799 3366991.674, 6265...
# 725   MULTILINESTRING ((626647.799 3366991.674, 6265...
# 1497  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 3258  MULTILINESTRING ((626647.799 3366991.674, 6265...
# 5490  MULTILINESTRING ((626647.799 3366991.674, 6265...
#
#       substantial_completion_date  substantial_completion_date_estimated  \
# 0       2008-01-01 06:00:00+00:00                                    NaT
# 725     2008-01-01 06:00:00+00:00                                    NaT
# 1497    2008-01-01 06:00:00+00:00                                    NaT
# 3258    2008-01-01 06:00:00+00:00                                    NaT
# 5490    2008-01-01 06:00:00+00:00                                    NaT
#
#      completion_date completion_end_date crash_project_component_id  \
# 0                NaT                 NaT         13118092-652-859.0
# 725              NaT                 NaT         18407113-652-859.0
# 1497             NaT                 NaT         13306837-652-859.0
# 3258             NaT                 NaT         13018929-652-859.0
# 5490             NaT                 NaT         18797163-652-859.0
#
#      pre_completion post_completion
# 0             False            True
# 725           False            True
# 1497          False            True
# 3258          False            True
# 5490          False            True
#
# [5 rows x 24 columns]

# %%
before_start
# Out:
# 0        2007-01-01 06:00:00+00:00
# 725      2007-01-01 06:00:00+00:00
# 1497     2007-01-01 06:00:00+00:00
# 3258     2007-01-01 06:00:00+00:00
# 5490     2007-01-01 06:00:00+00:00
#                     ...
# 411775   2022-10-03 05:00:00+00:00
# 411775   2020-11-01 05:00:00+00:00
# 411775   2020-11-01 05:00:00+00:00
# 413844   2022-10-03 05:00:00+00:00
# 415037   2014-03-15 05:00:00+00:00
# Name: substantial_completion_date, Length: 338181, dtype: datetime64[ns, UTC]

# %%
# Filter crashes for each time range
before_mask = (crashes_near_projects['crash_date'] >= before_start) & (crashes_near_projects['crash_date'] < crashes_near_projects['substantial_completion_date'])
after_mask = (crashes_near_projects['crash_date'] > crashes_near_projects['substantial_completion_date']) & (crashes_near_projects['crash_date'] <= after_end)

# Group by 'moped_component_id' and calculate the number of unique crashes before and after completion
before_group = crashes_near_projects[before_mask].groupby('moped_component_id')['crash_id'].nunique()
after_group = crashes_near_projects[after_mask].groupby('moped_component_id')['crash_id'].nunique()

# Calculate durations for each period
duration_before = crashes_near_projects.loc[before_mask, 'substantial_completion_date'] - crashes_near_projects.loc[before_mask, 'crash_date']
duration_before = duration_before.dt.total_seconds() / (365.25*24*60*60)  # Duration in years

duration_after = crashes_near_projects.loc[after_mask, 'crash_date'] - crashes_near_projects.loc[after_mask, 'substantial_completion_date']
duration_after = duration_after.dt.total_seconds() / (365.25*24*60*60)  # Duration in years

# Replace any NaNs or zero durations to avoid division by zero
duration_before.replace({0: 1e-6}, inplace=True)
duration_after.replace({0: 1e-6}, inplace=True)
duration_before.fillna(1e-6, inplace=True)
duration_after.fillna(1e-6, inplace=True)

# Annualize crash counts
annualized_before = before_group / duration_before
annualized_after = after_group / duration_after

# Combine results into a single DataFrame
results[label] = pd.DataFrame({
    f'annualized_before_{label}': annualized_before,
    f'annualized_after_{label}': annualized_after,
    f'before_{label}': before_group,
    f'after_{label}': after_group
}).fillna(0)  # Replace NaNs with 0 for components without crashes

# Combine all results into a single DataFrame for easier comparison
final_results = pd.concat(results.values(), axis=1)

# To convert annual rates to monthly and weekly rates:
final_results_filtered_before = final_results.filter(like='annualized_before_')
final_results_filtered_after = final_results.filter(like='annualized_after_')

final_results['monthly_rate_before'] = final_results_filtered_before.div(12, axis=0)
final_results['monthly_rate_after'] = final_results_filtered_after.div(12, axis=0)

final_results['weekly_rate_before'] = final_results_filtered_before.div(52, axis=0)
final_results['weekly_rate_after'] = final_results_filtered_after.div(52, axis=0)

# Export to CSV
final_results.to_csv('crash_counts_annualized_detailed.csv', index=True)

# Print final results to verify
print(final_results)

# %%
# Making the comparison richer by including different time ranges
time_ranges = {
    'year': pd.DateOffset(years=1),
    '6_months': pd.DateOffset(months=6),
    '1_month': pd.DateOffset(months=1),
    '1_week': pd.DateOffset(weeks=1)
}

# Dictionary to store results
results = {}

for label, offset in time_ranges.items():
    before_start = crashes_near_projects['substantial_completion_date'] - offset
    after_end = crashes_near_projects['substantial_completion_date'] + offset

    # Filter crashes for each time range
    before_mask = (crashes_near_projects['crash_date'] >= before_start) & (crashes_near_projects['crash_date'] < crashes_near_projects['substantial_completion_date'])
    after_mask = (crashes_near_projects['crash_date'] > crashes_near_projects['substantial_completion_date']) & (crashes_near_projects['crash_date'] <= after_end)

    # Group by 'moped_component_id' and calculate the number of unique crashes before and after completion
    before_group = crashes_near_projects[before_mask].groupby('moped_component_id')['crash_id'].nunique()
    after_group = crashes_near_projects[after_mask].groupby('moped_component_id')['crash_id'].nunique()

    # Calculate durations for each period
    duration_before = crashes_near_projects.loc[before_mask, 'substantial_completion_date'] - crashes_near_projects.loc[before_mask, 'crash_date']
    duration_before = duration_before.dt.total_seconds() / (365.25*24*60*60)  # Duration in years

    duration_after = crashes_near_projects.loc[after_mask, 'crash_date'] - crashes_near_projects.loc[after_mask, 'substantial_completion_date']
    duration_after = duration_after.dt.total_seconds() / (365.25*24*60*60)  # Duration in years

    # Replace any NaNs or zero durations to avoid division by zero
    duration_before.replace({0: 1e-6}, inplace=True)
    duration_after.replace({0: 1e-6}, inplace=True)
    duration_before.fillna(1e-6, inplace=True)
    duration_after.fillna(1e-6, inplace=True)
    
    # Annualize crash counts
    annualized_before = before_group / duration_before
    annualized_after = after_group / duration_after

    # Combine results into a single DataFrame
    results[label] = pd.DataFrame({
        f'annualized_before_{label}': annualized_before,
        f'annualized_after_{label}': annualized_after,
        f'before_{label}': before_group,
        f'after_{label}': after_group
    }).fillna(0)  # Replace NaNs with 0 for components without crashes

# Combine all results into a single DataFrame for easier comparison
final_results = pd.concat(results.values(), axis=1)

# To convert annual rates to monthly and weekly rates:
final_results_filtered_before = final_results.filter(like='annualized_before_')
final_results_filtered_after = final_results.filter(like='annualized_after_')

final_results['monthly_rate_before'] = final_results_filtered_before.div(12, axis=0)
final_results['monthly_rate_after'] = final_results_filtered_after.div(12, axis=0)

final_results['weekly_rate_before'] = final_results_filtered_before.div(52, axis=0)
final_results['weekly_rate_after'] = final_results_filtered_after.div(52, axis=0)

# Export to CSV
final_results.to_csv('crash_counts_annualized_detailed.csv', index=True)

# Print final results to verify
print(final_results)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 42
#      39     annualized_after = after_group / duration_after
#      41     # Combine results into a single DataFrame
# ---> 42     results[label] = pd.DataFrame({
#      43         f'annualized_before_{label}': annualized_before,
#      44         f'annualized_after_{label}': annualized_after,
#      45         f'before_{label}': before_group,
#      46         f'after_{label}': after_group
#      47     }).fillna(0)  # Replace NaNs with 0 for components without crashes
#      49 # Combine all results into a single DataFrame for easier comparison
#      50 final_results = pd.concat(results.values(), axis=1)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:119, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         index = ensure_index(index)
#     118     # don't force copy because getting jammed in an ndarray anyway
# --> 119     arrays, refs = _homogenize(arrays, index, dtype)
#     120     # _homogenize ensures
#     121     #  - all(len(x) == len(index) for x in arrays)
#     122     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     125
#     126 else:
#     127     index = ensure_index(index)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/construction.py:611, in _homogenize(data, index, dtype)
#     607     val = val.astype(dtype, copy=False)
#     608 if isinstance(val, ABCSeries) and val.index is not index:
#     609     # Forces alignment. No need to copy data since we
#     610     # are putting it into an ndarray later
# --> 611     val = val.reindex(index, copy=False)
#     612 refs.append(val._references)
#     613 val = val._values
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4981, in Series.reindex(self, index, axis, method, copy, level, fill_value, limit, tolerance)
#    4964 @doc(
#    4965     NDFrame.reindex,  # type: ignore[has-type]
#    4966     klass=_shared_doc_kwargs["klass"],
#    (...)
#    4979     tolerance=None,
#    4980 ) -> Series:
# -> 4981     return super().reindex(
#    4982         index=index,
#    4983         method=method,
#    4984         copy=copy,
#    4985         level=level,
#    4986         fill_value=fill_value,
#    4987         limit=limit,
#    4988         tolerance=tolerance,
#    4989     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5521, in NDFrame.reindex(self, labels, index, columns, axis, method, copy, level, fill_value, limit, tolerance)
#    5518     return self._reindex_multi(axes, copy, fill_value)
#    5520 # perform the reindex on the axes
# -> 5521 return self._reindex_axes(
#    5522     axes, level, limit, tolerance, method, fill_value, copy
#    5523 ).__finalize__(self, method="reindex")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:5544, in NDFrame._reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
#    5541     continue
#    5543 ax = self._get_axis(a)
# -> 5544 new_index, indexer = ax.reindex(
#    5545     labels, level=level, limit=limit, tolerance=tolerance, method=method
#    5546 )
#    5548 axis = self._get_axis_number(a)
#    5549 obj = obj._reindex_with_indexers(
#    5550     {axis: [new_index, indexer]},
#    5551     fill_value=fill_value,
#    5552     copy=copy,
#    5553     allow_dups=False,
#    5554 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:4434, in Index.reindex(self, target, method, level, limit, tolerance)
#    4431     raise ValueError("cannot handle a non-unique multi-index!")
#    4432 elif not self.is_unique:
#    4433     # GH#42568
# -> 4434     raise ValueError("cannot reindex on an axis with duplicate labels")
#    4435 else:
#    4436     indexer, _ = self.get_indexer_non_unique(target)
#
# ValueError: cannot reindex on an axis with duplicate labels

# %%
# Group by 'moped_component_id' and calculate the number of unique crashes before and after completion
pre_group = crashes_near_projects[crashes_near_projects['pre_completion']].groupby('moped_component_id')['crash_id'].nunique()
post_group = crashes_near_projects[crashes_near_projects['post_completion']].groupby('moped_component_id')['crash_id'].nunique()

# Combine results into a DataFrame for clarity
results = pd.DataFrame({
    'pre_completion': pre_group,
    'post_completion': post_group
}).fillna(0)  # Replace NaNs with 0 for components without crashes

print(results)

# %%
results.to_csv('crash_counts.csv', index=True)
